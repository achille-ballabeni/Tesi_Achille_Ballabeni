# %% [markdown]
# # Dataset loading

# %% [markdown]
# Download datasets.

# %%
# !gdown https://drive.google.com/file/d/1aQ_mpyoxlQ2OgJ7vXkPk04sogAIpbyNF/view?usp=sharing --fuzzy
# !gdown https://drive.google.com/file/d/1-1bTtmmSau_o4MHBqT_FizS0-x_TwH4z/view?usp=sharing --fuzzy
# !gdown https://drive.google.com/file/d/1-4T8FSnJK0PZmOuwS295BTg68lA5Q49-/view?usp=sharing --fuzzy
# !gdown https://drive.google.com/file/d/1-7gXamdIWTDISiyOu40bd0xCfg1Q4a-O/view?usp=sharing --fuzzy
# !gdown https://drive.google.com/file/d/1-8A598Uqj2RV705DaFF5HdM2X12bowFx/view?usp=sharing --fuzzy

# %% [markdown]
# Define loading paths.

# %%
tf_records_path = '/content/split_{}.record'

# %% [markdown]
# # Dataset decoding

# %% [markdown]
# Define a set of decoding functions.

# %%
import tensorflow as tf
import numpy as np

def load_tf_records(filepath):
    filenames = tf.io.gfile.glob(filepath)
    dataset = tf.data.TFRecordDataset(filenames,num_parallel_reads=tf.data.experimental.AUTOTUNE)
    return dataset

def tf_records_file_features_description():
    image_feature_description = {
        
        'image/height': tf.io.FixedLenFeature([], tf.int64),
        'image/width': tf.io.FixedLenFeature([], tf.int64),
        'image': tf.io.FixedLenFeature([],tf.string),
        'label/P': tf.io.FixedLenFeature([], tf.float32),
        'label/K': tf.io.FixedLenFeature([], tf.float32),
        'label/Mg': tf.io.FixedLenFeature([], tf.float32),
        'label/Ph': tf.io.FixedLenFeature([], tf.float32),
    }
    return image_feature_description

def decode_dataset(example_proto):
    features=tf.io.parse_single_example(example_proto, tf_records_file_features_description())

    image=features['image']
    height=features['image/height']
    width=features['image/width']
    image=tf.io.decode_raw(image,tf.int16)
    image=tf.reshape(image,[height,width,150])

    P=features['label/P']
    K=features['label/K']
    Mg=features['label/Mg']
    Ph=features['label/Ph']

    height=features['image/height']
    width=features['image/width']

    label=[P,K,Mg,Ph]

    return image, label, height, width

# %% [markdown]
# #Dataset analysis
# This section performs some basic analysis on the dataset which drove the NN design.
#
# It is not required to run this section to train the model.

# %% [markdown]
# Load train and test datasets.

# %%
# Load dataset partitions

splits = [load_tf_records(tf_records_path.format(i)).map(decode_dataset, num_parallel_calls=tf.data.AUTOTUNE) for i in range(1,6)]

# %% [markdown]
# Concatenate dataset partitions for analysis purposes.

# %%
full_dataset = splits[0].concatenate(splits[1]).concatenate(splits[2]).concatenate(splits[3]).concatenate(splits[4])

# %% [markdown]
# Show dataset sizes.

# %%
#[len(list(partition)) for partition in splits] #High RAM usage
num_images = [346, 346, 346, 347, 347]
print('Number of images in each partition: ', num_images)
total_num_images = sum(num_images)
print('Total number of images: ', total_num_images)
# Out:
# Number of images in each partition:  [346, 346, 346, 347, 347]
# Total number of images:  1732

# %% [markdown]
# Find maximum and minimum intensity values for both datasets.

# %%
# Find maximum reflectance

def find_max(dataset):                      
    max = 0
    for image, label, height, width in dataset:
        max_reflectance = np.amax(image)
        if max_reflectance > max:
            max = max_reflectance
    return(max)

# Find minimum reflectance

def find_min(dataset, min):
    for image, label, height, width in dataset:
        min_reflectance = np.amin(image)
        if min_reflectance < min:
            min = min_reflectance
    return(min)

# %%
max_reflectance_overall = find_max(full_dataset)
min_reflectance_overall = find_min(full_dataset, max_reflectance_overall)
print('Max reflectance overall:', max_reflectance_overall)
print('Min reflectance overall:', min_reflectance_overall)
# Out:
# Max reflectance overall: 5419
# Min reflectance overall: -3

# %% [markdown]
# Find maximum height and width of images in both datasets.

# %%
shape_data = np.array(list(full_dataset.map(lambda image, label, height, width: tf.shape(image)[0:2]).as_numpy_iterator()))
h_dims, w_dims = np.hsplit(shape_data, 2)

max_height = np.amax(h_dims)
max_width = np.amax(w_dims)
print('Max height train:', max_height)
print('Max width train:', max_width)
# Out:
# Max height train: 268
# Max width train: 284

# %% [markdown]
# Show image size distribution in a bar chart.

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(1, 1, figsize=(12,5))

plt.subplots_adjust(wspace=0.1, hspace=0.4, right=0.85)

n_h, bins_h, patches_h = axs.hist(h_dims, bins='auto')
axs.set_title('Height distribution')
axs.set_xlabel('Image height [px]')
axs.set_ylabel('Frequency')
axs.set_xticks(bins_h)
axs.grid(color='white', lw = 0.5, axis='x')
axs.title.set_size(15)
axs.xaxis.label.set_size(13)
axs.yaxis.label.set_size(13)
axs.tick_params(axis='x', labelrotation=45, labelsize=13)
axs.tick_params(axis='y', labelsize=13)

fig, axs = plt.subplots(1, 1, figsize=(12,5))

plt.subplots_adjust(wspace=0.1, hspace=0.4, right=0.85)

n_w, bins_w, patches_w = axs.hist(w_dims, bins='auto')
axs.set_title('Width distribution')
axs.set_xlabel('Image width [px]')
axs.set_ylabel('Frequency')
axs.set_xticks(bins_w)
axs.grid(color='white', lw = 0.5, axis='x')
axs.title.set_size(15)
axs.xaxis.label.set_size(13)
axs.yaxis.label.set_size(13)
axs.tick_params(axis='x', labelrotation=45, labelsize=13)
axs.tick_params(axis='y', labelsize=13)

plt.show()

# %% [markdown]
# # Dataset preprocessing

# %%
from tensorflow import keras
from keras import layers
import matplotlib.pyplot as plt
import pandas as pd
import os
import random as rn
rn.seed(2)
np.random.seed(3)
tf.random.set_seed(1)

AUTO = tf.data.AUTOTUNE

# %% [markdown]
# Define preprocessing values.

# %%
max_reflectance_overall = 5419
max_reflectance_PCA = 6.282844

max_height = 268
max_width = 284

total_num_images = 1732
num_images = [346, 346, 346, 347, 347]

max_gt_values = [325, 625, 400, 14]

mse_baseline = [8.7002814e+02, 3.8284080e+03, 1.5888525e+03, 6.7716144e-02]

n_bands = 5

# !gdown https://drive.google.com/file/d/12NScF4TLmZXx2oo-hfEfbkqgi6IYMmiO/view?usp=sharing --fuzzy
std_vec = tf.cast(tf.reshape(np.load('/content/std_vector.npy'), [150]), dtype='float32')

# !gdown https://drive.google.com/file/d/1JkHm7rm-qMEhuQYXOeOlx0RaO-7Hxk10/view?usp=sharing --fuzzy
informative_bands = tf.cast(np.load('/content/informative_bands.npy')-1, dtype='int32')
band_selection_index = tf.squeeze(informative_bands[:n_bands])

# %%
# Define preprocessing functions for the train dataset
target_image_size = 32

def normalize_train(image, label, height, width, std_vec, max_gt_values):    #Function to normalize the train dataset
    
    image = tf.cast(image,tf.float32)
    image = image/std_vec
    label /= max_gt_values

    return image, label, height, width

def make_horizontal_patch_train(patch, nx):    #Function that repeats a patch horizontally with random flips
    
    hor_patch = tf.image.random_flip_left_right(tf.image.random_flip_up_down(patch, seed=72), seed=64)
    i=0

    def cond(hor_patch, patch, i, nx):
        return tf.less(i, nx-1)
    def body(hor_patch, patch, i, nx):
        hor_patch = tf.concat([hor_patch, tf.image.random_flip_left_right(tf.image.random_flip_up_down(patch, seed=49), seed=95)], 1)
        i+=1
        return hor_patch, patch, i, nx

    hor_patch, _, _, _ = tf.while_loop(cond, body, [hor_patch, patch, i, nx])

    return hor_patch

def image_repetition_train(image, height, width):    #Function that repeats small images applying random flips to create a bigger image
    
    nx = tf.math.floordiv(target_image_size, tf.cast(width, tf.int32))
    ny = tf.math.floordiv(target_image_size, tf.cast(height, tf.int32))
    patch = image
    image = make_horizontal_patch_train(patch, nx)
    i=0

    def cond(image, patch, i, ny):
        return tf.less(i, ny-1)
    def body(image, patch, i, ny):
        image = tf.concat([image, make_horizontal_patch_train(patch, nx)], 0)
        i+=1
        return image, patch, i, ny
    
    image, _, _, _= tf.while_loop(cond, body, [image, patch, i, ny])

    image = tf.cond(tf.math.maximum(nx, ny)==1, lambda: tf.image.resize(image, [target_image_size, target_image_size], method='bilinear', antialias=False), lambda: tf.image.pad_to_bounding_box(image, 0, 0, target_image_size, target_image_size))

    return image

def pad_with_patches_train(image, label, height, width, n_bands):    #Function to resize images to [32,32,n_bands]
    
    max_dim = tf.math.maximum(height, width)
    image = tf.cond(max_dim<target_image_size, lambda: image_repetition_train(image, height, width), lambda: tf.image.resize(image, [target_image_size, target_image_size], method='bilinear', antialias=False))
    image = add_gauss_noise(image, n_bands)

    index=tf.random.uniform(shape=[],maxval=4,dtype=tf.dtypes.int32,seed=32)
    
    image=tf.cond(tf.equal(index,1),lambda: tf.image.flip_left_right(image), lambda: image)

    image=tf.cond(tf.equal(index,2),lambda: tf.image.flip_up_down(image), lambda: image)

    image=tf.cond(tf.equal(index,3),lambda: tf.image.flip_left_right(tf.image.flip_up_down(image)), lambda: image)

    return image, label

def add_gauss_noise(image, n_bands):
  
    mean = 0
    std = 0.05
      
    gauss = tf.random.normal([target_image_size, target_image_size, n_bands], mean, std, seed=910)

    noisy = image + gauss

    return noisy

def select_bands(image, label, height, width, band_index):

    image = tf.gather(image, band_index, axis = 2)

    return image, label, height, width

# %% [markdown]
# Training setup.

# %%
test_partition_id = 5
num_train_images = total_num_images - num_images[test_partition_id-1]

epochs = 400
batch_size = 32
steps_per_epoch = num_train_images//batch_size

# %% [markdown]
# Dataset mapping (tf.data.Dataset API).

# %%
# Concatenate partitions to form the train set, the partition chosen as the test partition is excluded
splits = [load_tf_records(tf_records_path.format(i)).map(decode_dataset, num_parallel_calls=tf.data.AUTOTUNE) for i in range(1,6)]
index = list(range(5))
index.pop(test_partition_id-1)

ds = splits[index[0]]
index.pop(0)

for i in index:
    ds = ds.concatenate(splits[i])


train_data = ds.take(1376)
train_data = train_data.map(lambda image, label, height, width: normalize_train(image, label, height, width, std_vec, max_gt_values), num_parallel_calls=AUTO)    #normalize train dataset
train_data = train_data.map(lambda image, label, height, width: select_bands(image, label, height, width, band_selection_index), num_parallel_calls=AUTO).cache()    #apply band selection
train_data = train_data.shuffle(num_train_images, seed=1866)    #shuffle train dataset
train_data = train_data.map(lambda image, label, height, width: pad_with_patches_train(image, label, height, width, n_bands), num_parallel_calls=AUTO)    #pad test dataset
train_data = train_data.batch(batch_size=batch_size, drop_remainder=True)    #batch train dataset
train_data = train_data.prefetch(AUTO)    #prefetch train dataset

val_data = ds.skip(1376)    #create validation dataset from the last elements of the train dataset that are discarded during batching
val_data =val_data.map(lambda image, label, height, width: normalize_train(image, label, height, width, std_vec, max_gt_values), num_parallel_calls=AUTO)    #normalize validation dataset 
val_data = val_data.map(lambda image, label, height, width: select_bands(image, label, height, width, band_selection_index), num_parallel_calls=AUTO).cache()    #apply band selection
val_data = val_data.map(lambda image, label, height, width: pad_with_patches_train(image, label, height, width, n_bands), num_parallel_calls=AUTO)    #pad validation dataset
val_data = val_data.batch(batch_size=10, drop_remainder=False)    #batch validation dataset
val_data = val_data.prefetch(AUTO)    #prefetch validation dataset

# %% [markdown]
# Print the bands for some training images.

# %%
n_images = 10
k = min(n_bands, 10)

for image, label in train_data.unbatch().take(n_images):
    fig, axs = plt.subplots(1, k, figsize=(25*k/10, 7*k/10))
    for i in range(k):
        axs[i].imshow(image[:,:,i])

plt.show()

# %% [markdown]
# Print the validation set.

# %%
k = min(n_bands, 10)

for image, label in val_data.unbatch():
    fig, axs = plt.subplots(1, k, figsize=(25*k/10, 7*k/10))
    for i in range(k):
        axs[i].imshow(image[:,:,i])

plt.show()

# %% [markdown]
# # Build and train NN model
# EfficientNet-Lite: the following cell is adapted from https://github.com/sebastian-sz/efficientnet-lite-keras, distributed under Apache License 2.0. We defined a new "EfficientNetLiteB0mod" setting width and depth to 0.5.

# %%
import copy
import math

import tensorflow as tf
from tensorflow.keras import layers

if tf.__version__ < "2.8":  # Keras has been moved to separate repository
    from tensorflow.python.keras.applications import imagenet_utils
else:
    from keras.applications import imagenet_utils

from tensorflow.python.keras import backend
from tensorflow.python.keras.utils import layer_utils
from tensorflow.python.lib.io import file_io

DEFAULT_BLOCKS_ARGS = [
    {
        "kernel_size": 3,
        "repeats": 1,
        "filters_in": 32,
        "filters_out": 16,
        "expand_ratio": 1,
        "id_skip": True,
        "strides": 1,
    },
    {
        "kernel_size": 3,
        "repeats": 2,
        "filters_in": 16,
        "filters_out": 24,
        "expand_ratio": 6,
        "id_skip": True,
        "strides": 2,
    },
    {
        "kernel_size": 5,
        "repeats": 2,
        "filters_in": 24,
        "filters_out": 40,
        "expand_ratio": 6,
        "id_skip": True,
        "strides": 2,
    },
    {
        "kernel_size": 3,
        "repeats": 3,
        "filters_in": 40,
        "filters_out": 80,
        "expand_ratio": 6,
        "id_skip": True,
        "strides": 2,
    },
    {
        "kernel_size": 5,
        "repeats": 3,
        "filters_in": 80,
        "filters_out": 112,
        "expand_ratio": 6,
        "id_skip": True,
        "strides": 1,
    },
    {
        "kernel_size": 5,
        "repeats": 4,
        "filters_in": 112,
        "filters_out": 192,
        "expand_ratio": 6,
        "id_skip": True,
        "strides": 2,
    },
    {
        "kernel_size": 3,
        "repeats": 1,
        "filters_in": 192,
        "filters_out": 320,
        "expand_ratio": 6,
        "id_skip": True,
        "strides": 1,
    },
]

CONV_KERNEL_INITIALIZER = {
    "class_name": "VarianceScaling",
    "config": {"scale": 2.0, "mode": "fan_out", "distribution": "truncated_normal"},
}

DENSE_KERNEL_INITIALIZER = {
    "class_name": "VarianceScaling",
    "config": {"scale": 1.0 / 3.0, "mode": "fan_out", "distribution": "uniform"},
}

WEIGHTS_BASE_URL = (
    "https://github.com/sebastian-sz/efficientnet-lite-keras/releases/download/v1.0/"
)
WEIGHTS_HASHES = {
    "efficientnet_lite_b0.h5": "8236b3edc4bd9019865ffd8290cf0b05",
    "efficientnet_lite_b0_notop.h5": "d7a91a3c0e7f0bdffe67f599ebe511cd",
    "efficientnet_lite_b1.h5": "8684671aebaf23b7fb03a0e10fbea162",
    "efficientnet_lite_b1_notop.h5": "9fece5f941068bf189913cd5b42439bf",
    "efficientnet_lite_b2.h5": "e3c7128846d3297734ec7465cb171989",
    "efficientnet_lite_b2_notop.h5": "d0b7d56925cc4b82e30a45570766b32e",
    "efficientnet_lite_b3.h5": "f6a5df9c63310630a5a7f9bcc45c9598",
    "efficientnet_lite_b3_notop.h5": "7ae45c1c6cb1d2ba5193d131984a2225",
    "efficientnet_lite_b4.h5": "25b9276e711f82443523df227aa32cad",
    "efficientnet_lite_b4_notop.h5": "8939585df7b434869381f7786dc60290",
}


def EfficientNetLite(
    width_coefficient,
    depth_coefficient,
    default_size,
    dropout_rate=0.2,
    drop_connect_rate=0.2,
    depth_divisor=8,
    blocks_args="default",
    model_name="efficientnet",
    include_top=True,
    weights="imagenet",
    input_tensor=None,
    input_shape=None,
    pooling=None,
    classes=1000,
    classifier_activation="softmax",
):
    """
    Instantiate the EfficientNet architecture using given scaling coefficients.

    Args:
        width_coefficient: float, scaling coefficient for network width.
        depth_coefficient: float, scaling coefficient for network depth.
        default_size: integer, default input image size.
        dropout_rate: float, dropout rate before final classifier layer.
        drop_connect_rate: float, dropout rate at skip connections.
        depth_divisor:  integer, a unit of network width.
        blocks_args: list of dicts, parameters to construct block modules.
        model_name: string, model name.
        include_top: whether to include the fully-connected
            layer at the top of the network.
        weights: 'imagenet' or path to weights file.
        input_tensor: optional Keras tensor
            (i.e. output of `layers.Input()`)
            to use as image input for the model.
        input_shape: optional shape tuple, only to be specified
            if `include_top` is False.
            It should have exactly 3 inputs channels.
        pooling: when `include_top` is `False`.
            - `None` means that the output of the model will be
                the 4D tensor output of the
                last convolutional layer.
            - `avg` means that global average pooling
                will be applied to the output of the
                last convolutional layer, and thus
                the output of the model will be a 2D tensor.
            - `max` means that global max pooling will
                be applied.
        classes: optional number of classes to classify images
            into, only to be specified if `include_top` is True, and
            if no `weights` argument is specified.
        classifier_activation: A `str` or callable.
            The activation function to use on the "top" layer. Ignored unless
            `include_top=True`. Set`classifier_activation=None`
            to return the logits of the "top" layer.

    Returns:
        A `keras.Model` instance.

    Raises:
        ValueError: in case of invalid argument for `weights`,
            or invalid input shape.
        ValueError: if `classifier_activation` is not `softmax` or `None` when
            using a pretrained top layer.
    """
    if blocks_args == "default":
        blocks_args = DEFAULT_BLOCKS_ARGS

    if not (weights in {"imagenet", None} or file_io.file_exists_v2(weights)):
        raise ValueError(
            "The `weights` argument should be either "
            "`None` (random initialization), `imagenet` "
            "(pre-training on ImageNet), "
            "or the path to the weights file to be loaded."
        )

    if weights == "imagenet" and include_top and classes != 1000:
        raise ValueError(
            'If using `weights` as `"imagenet"` with `include_top`'
            " as true, `classes` should be 1000"
        )

    # Determine proper input shape
    input_shape = imagenet_utils.obtain_input_shape(
        input_shape,
        default_size=default_size,
        min_size=32,
        data_format=backend.image_data_format(),
        require_flatten=include_top,
        weights=weights,
    )
    if input_tensor is None:
        img_input = layers.Input(shape=input_shape)
    else:
        if not backend.is_keras_tensor(input_tensor):
            img_input = layers.Input(tensor=input_tensor, shape=input_shape)
        else:
            img_input = input_tensor

    bn_axis = 3 if backend.image_data_format() == "channels_last" else 1

    def round_filters(filters, divisor=depth_divisor):
        """Round number of filters based on depth multiplier."""
        filters *= width_coefficient
        new_filters = max(divisor, int(filters + divisor / 2) // divisor * divisor)
        # Make sure that round down does not go down by more than 10%.
        if new_filters < 0.9 * filters:
            new_filters += divisor
        return int(new_filters)

    def round_repeats(repeats):
        """Round number of repeats based on depth multiplier."""
        return int(math.ceil(depth_coefficient * repeats))

    # Build stem
    x = img_input

    x = layers.ZeroPadding2D(
        padding=imagenet_utils.correct_pad(x, 3), name="stem_conv_pad"
    )(x)
    x = layers.Conv2D(
        32,
        3,
        strides=2,
        padding="valid",
        use_bias=False,
        kernel_initializer=CONV_KERNEL_INITIALIZER,
        name="stem_conv",
    )(x)
    x = layers.BatchNormalization(axis=bn_axis, name="stem_bn")(x)
    x = layers.ReLU(max_value=6, name="stem_activation")(x)

    # Build blocks
    blocks_args = copy.deepcopy(blocks_args)
    b = 0
    blocks = float(sum(args["repeats"] for args in blocks_args))

    for (i, args) in enumerate(blocks_args):
        assert args["repeats"] > 0
        # Update block input and output filters based on depth multiplier.
        args["filters_in"] = round_filters(args["filters_in"])
        args["filters_out"] = round_filters(args["filters_out"])

        if i == 0 or i == (len(blocks_args) - 1):
            repeats = args.pop("repeats")
        else:
            repeats = round_repeats(args.pop("repeats"))

        for j in range(repeats):
            # The first block needs to take care of stride and filter size increase.
            if j > 0:
                args["strides"] = 1
                args["filters_in"] = args["filters_out"]
            x = block(
                x,
                drop_connect_rate * b / blocks,
                name="block{}{}_".format(i + 1, chr(j + 97)),
                **args,
            )

            b += 1
    # Build top
    x = layers.Conv2D(
        1280,
        1,
        padding="same",
        use_bias=False,
        kernel_initializer=CONV_KERNEL_INITIALIZER,
        name="top_conv",
    )(x)
    x = layers.BatchNormalization(axis=bn_axis, name="top_bn")(x)
    x = layers.ReLU(max_value=6, name="top_activation")(x)

    if include_top:
        x = layers.GlobalAveragePooling2D(name="avg_pool")(x)
        if dropout_rate > 0:
            x = layers.Dropout(dropout_rate, name="top_dropout")(x)
        imagenet_utils.validate_activation(classifier_activation, weights)
        x = layers.Dense(
            classes,
            activation=classifier_activation,
            kernel_initializer=DENSE_KERNEL_INITIALIZER,
            name="predictions",
        )(x)
    else:
        if pooling == "avg":
            x = layers.GlobalAveragePooling2D(name="avg_pool")(x)
        elif pooling == "max":
            x = layers.GlobalMaxPooling2D(name="max_pool")(x)

    # Ensure that the model takes into account
    # any potential predecessors of `input_tensor`.
    if input_tensor is not None:
        inputs = layer_utils.get_source_inputs(input_tensor)
    else:
        inputs = img_input

    # Create model.
    model = tf.keras.Model(inputs, x, name=model_name)

    # Load weights.
    if weights == "imagenet":
        model_variant = "efficientnet_lite_b" + model_name[-1]

        if not include_top:
            model_variant += "_notop"

        filename = f"{model_variant}.h5"
        download_url = WEIGHTS_BASE_URL + filename
        weights_path = tf.keras.utils.get_file(
            fname=filename,
            origin=download_url,
            cache_subdir="models",
            file_hash=WEIGHTS_HASHES[filename],
        )
        model.load_weights(weights_path)

    elif weights is not None:
        model.load_weights(weights)

    return model


def block(
    inputs,
    drop_rate=0.0,
    name="",
    filters_in=32,
    filters_out=16,
    kernel_size=3,
    strides=1,
    expand_ratio=1,
    id_skip=True,
):
    """
    Create an inverted residual block.

    Args:
        inputs: input tensor.
        drop_rate: float between 0 and 1, fraction of the input units to drop.
        name: string, block label.
        filters_in: integer, the number of input filters.
        filters_out: integer, the number of output filters.
        kernel_size: integer, the dimension of the convolution window.
        strides: integer, the stride of the convolution.
        expand_ratio: integer, scaling coefficient for the input filters.
        id_skip: boolean.

    Returns:
        output tensor for the block.
    """
    bn_axis = 3 if backend.image_data_format() == "channels_last" else 1
    # Expansion phase
    filters = filters_in * expand_ratio
    if expand_ratio != 1:
        x = layers.Conv2D(
            filters,
            1,
            padding="same",
            use_bias=False,
            kernel_initializer=CONV_KERNEL_INITIALIZER,
            name=name + "expand_conv",
        )(inputs)
        x = layers.BatchNormalization(axis=bn_axis, name=name + "expand_bn")(x)
        x = layers.ReLU(max_value=6, name=name + "expand_activation")(x)
    else:
        x = inputs

    # Depthwise Convolution
    if strides == 2:
        x = layers.ZeroPadding2D(
            padding=imagenet_utils.correct_pad(x, kernel_size), name=name + "dwconv_pad"
        )(x)
        conv_pad = "valid"
    else:
        conv_pad = "same"
    x = layers.DepthwiseConv2D(
        kernel_size,
        strides=strides,
        padding=conv_pad,
        use_bias=False,
        depthwise_initializer=CONV_KERNEL_INITIALIZER,
        name=name + "dwconv",
    )(x)
    x = layers.BatchNormalization(axis=bn_axis, name=name + "bn")(x)
    x = layers.ReLU(max_value=6, name=name + "activation")(x)

    # Skip SE

    # Output phase
    x = layers.Conv2D(
        filters_out,
        1,
        padding="same",
        use_bias=False,
        kernel_initializer=CONV_KERNEL_INITIALIZER,
        name=name + "project_conv",
    )(x)
    x = layers.BatchNormalization(axis=bn_axis, name=name + "project_bn")(x)
    if id_skip and strides == 1 and filters_in == filters_out:
        if drop_rate > 0:
            x = layers.Dropout(
                drop_rate, noise_shape=(None, 1, 1, 1), name=name + "drop"
            )(x)
        x = layers.add([x, inputs], name=name + "add")
    return x


def EfficientNetLiteB0mod(
    include_top=False,
    weights="imagenet",
    input_tensor=None,
    input_shape=None,
    pooling=None,
    classes=1000,
    classifier_activation="softmax",
    **kwargs,
):
    """Create Efficient Net Lite B0 variant."""
    return EfficientNetLite(
        0.5,
        0.5,
        224,
        0.1,
        model_name="efficientnetlite0",
        include_top=include_top,
        weights=weights,
        input_tensor=input_tensor,
        input_shape=input_shape,
        pooling=pooling,
        classes=classes,
        classifier_activation=classifier_activation,
        **kwargs,
    )

# %% [markdown]
# Learning rate scheduling.

# %%
start_lr = 0.005 #*256/batch_size
alpha = 0.0001
decay_steps = epochs

def lr_scheduler(epoch, start_lr):
    if epoch < 1:
      lr = (start_lr-0.001)/1*epoch+0.001
    else:
      cosine_decay = 0.5 * (1 + tf.cos(np.pi * epoch / (decay_steps)))
      decayed = (1 - alpha) * cosine_decay + alpha
      lr = start_lr * decayed
    return lr

lr_callback = tf.keras.callbacks.LearningRateScheduler(lambda epoch: lr_scheduler(epoch, start_lr), verbose=1)

#Plot learning rate

x_range = np.arange(epochs)
y = [lr_scheduler(x, start_lr) for x in x_range]
plt.plot(x_range, y)
print('Learning rate per epoch:')
# Out:
# Learning rate per epoch:

# %% [markdown]
# Create and compile the model.

# %%
network_name = 'EfficientNetLiteB0mod12_GPU_32px_band_selection_cross_validation_' + str(n_bands) + 'bands'

base_model = EfficientNetLiteB0mod(input_shape=(target_image_size, target_image_size, n_bands), weights=None) #multiplo di 32
model = tf.keras.Sequential([base_model,  
                                layers.Flatten(),
                                    layers.Dense(4, kernel_initializer=tf.keras.initializers.GlorotUniform(seed=1509))])

def custom_metric(y_true, y_pred):
    y_true = tf.multiply(y_true, max_gt_values)
    y_pred = tf.multiply(y_pred, max_gt_values)
    mse = tf.reduce_mean((y_true-y_pred)**2, axis=0)
    score = tf.reduce_mean(mse/mse_baseline)

    return score

opt = keras.optimizers.Adam(clipnorm=1.)
model.compile(
    optimizer=opt,
    loss='mse',
    metrics=[custom_metric],
  )

model.summary()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:198: UserWarning: This model usually expects 1 or 3 input channels. However, it was passed an input_shape with 5 input channels.
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetlite0 (Function  (None, 1, 1, 1280)       687136
#  al)
#
#  flatten_5 (Flatten)         (None, 1280)              0
#
#  dense_5 (Dense)             (None, 4)                 5124
#
# =================================================================
# Total params: 692,260
# Trainable params: 678,020
# Non-trainable params: 14,240
# _________________________________________________________________

# %% [markdown]
# Define saving paths.

# %%
base_path = '/content/'

checkpoint_filepath = base_path + network_name + '/checkpoint_' + str(test_partition_id) 
predictions_filepath = base_path + network_name + '/predictions_' + str(test_partition_id) + '.csv'

print(checkpoint_filepath)
print(predictions_filepath)

# %% [markdown]
# Train the model.

# %%
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_filepath, save_best_only=True, monitor='custom_metric', mode='min')

History = model.fit(train_data, epochs=epochs, callbacks=[lr_callback], validation_data=val_data)
# Out:
# Epoch 1: LearningRateScheduler setting learning rate to 0.001.
# Epoch 1/400
# 43/43 [==============================] - 8s 57ms/step - loss: 0.4069 - custom_metric: 290.3523 - val_loss: 0.1042 - val_custom_metric: 165.4579 - lr: 0.0010
#
# Epoch 2: LearningRateScheduler setting learning rate to 0.004999923054128885.
# Epoch 2/400
# 43/43 [==============================] - 2s 43ms/step - loss: 0.4209 - custom_metric: 297.5938 - val_loss: 0.0217 - val_custom_metric: 4.7905 - lr: 0.0050
#
# Epoch 3: LearningRateScheduler setting learning rate to 0.004999691620469093.
# Epoch 3/400
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0443 - custom_metric: 25.2092 - val_loss: 0.0070 - val_custom_metric: 7.1115 - lr: 0.0050
#
# Epoch 4: LearningRateScheduler setting learning rate to 0.0049993060529232025.
# Epoch 4/400
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0376 - custom_metric: 17.7026 - val_loss: 0.0055 - val_custom_metric: 2.3770 - lr: 0.0050
#
# Epoch 5: LearningRateScheduler setting learning rate to 0.0049987658858299255.
# Epoch 5/400
# 43/43 [==============================] - 2s 44ms/step - loss: 0.0308 - custom_metric: 19.9190 - val_loss: 0.0090 - val_custom_metric: 3.3318 - lr: 0.0050
#
# Epoch 6: LearningRateScheduler setting learning rate to 0.004998072516173124.
# Epoch 6/400
# 43/43 [==============================] - 2s 43ms/step - loss: 0.0502 - custom_metric: 19.5996 - val_loss: 0.0222 - val_custom_metric: 3.1666 - lr: 0.0050
#
# Epoch 7: LearningRateScheduler setting learning rate to 0.004997225012630224.
# Epoch 7/400
# 43/43 [==============================] - 2s 44ms/step - loss: 0.0320 - custom_metric: 15.2430 - val_loss: 0.0198 - val_custom_metric: 7.3596 - lr: 0.0050
#
# Epoch 8: LearningRateScheduler setting learning rate to 0.004996222909539938.
# Epoch 8/400
# 43/43 [==============================] - 2s 44ms/step - loss: 0.0256 - custom_metric: 11.8285 - val_loss: 0.0070 - val_custom_metric: 3.0513 - lr: 0.0050
#
# Epoch 9: LearningRateScheduler setting learning rate to 0.00499506713822484.
# Epoch 9/400
# 43/43 [==============================] - 2s 44ms/step - loss: 0.0273 - custom_metric: 29.5350 - val_loss: 0.0060 - val_custom_metric: 0.9246 - lr: 0.0050
#
# Epoch 10: LearningRateScheduler setting learning rate to 0.004993757698684931.
# Epoch 10/400
# 43/43 [==============================] - 2s 44ms/step - loss: 0.0245 - custom_metric: 19.7809 - val_loss: 0.0098 - val_custom_metric: 1.2119 - lr: 0.0050
#
# Epoch 11: LearningRateScheduler setting learning rate to 0.004992294125258923.
# Epoch 11/400
# 43/43 [==============================] - 2s 44ms/step - loss: 0.0260 - custom_metric: 25.9856 - val_loss: 0.0084 - val_custom_metric: 6.8915 - lr: 0.0050
#
# Epoch 12: LearningRateScheduler setting learning rate to 0.004990676883608103.
# Epoch 12/400
# 43/43 [==============================] - 2s 44ms/step - loss: 0.0223 - custom_metric: 12.0231 - val_loss: 0.0059 - val_custom_metric: 1.8358 - lr: 0.0050
#
# Epoch 13: LearningRateScheduler setting learning rate to 0.0049889059737324715.
# Epoch 13/400
# 43/43 [==============================] - 2s 44ms/step - loss: 0.0202 - custom_metric: 9.8118 - val_loss: 0.0147 - val_custom_metric: 2.0643 - lr: 0.0050
#
# Epoch 14: LearningRateScheduler setting learning rate to 0.004986981861293316.
# Epoch 14/400
# 43/43 [==============================] - 2s 44ms/step - loss: 0.0243 - custom_metric: 9.7434 - val_loss: 0.0047 - val_custom_metric: 0.8864 - lr: 0.0050
#
# Epoch 15: LearningRateScheduler setting learning rate to 0.0049849036149680614.
# Epoch 15/400
# 43/43 [==============================] - 2s 44ms/step - loss: 0.0158 - custom_metric: 8.5974 - val_loss: 0.0072 - val_custom_metric: 1.8196 - lr: 0.0050
#
# Epoch 16: LearningRateScheduler setting learning rate to 0.00498267263174057.
# Epoch 16/400
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0203 - custom_metric: 5.9288 - val_loss: 0.0068 - val_custom_metric: 1.1174 - lr: 0.0050
#
# Epoch 17: LearningRateScheduler setting learning rate to 0.004980288911610842.
# Epoch 17/400
# 43/43 [==============================] - 2s 44ms/step - loss: 0.0179 - custom_metric: 5.5804 - val_loss: 0.0067 - val_custom_metric: 0.9733 - lr: 0.0050
#
# Epoch 18: LearningRateScheduler setting learning rate to 0.004977751523256302.
# Epoch 18/400
# 43/43 [==============================] - 2s 44ms/step - loss: 0.0233 - custom_metric: 8.7844 - val_loss: 0.0045 - val_custom_metric: 1.6178 - lr: 0.0050
#
# Epoch 19: LearningRateScheduler setting learning rate to 0.004975061397999525.
# Epoch 19/400
# 43/43 [==============================] - 2s 44ms/step - loss: 0.0259 - custom_metric: 11.8092 - val_loss: 0.0107 - val_custom_metric: 1.8723 - lr: 0.0050
#
# Epoch 20: LearningRateScheduler setting learning rate to 0.004972218535840511.
# Epoch 20/400
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0182 - custom_metric: 5.5440 - val_loss: 0.0076 - val_custom_metric: 3.4935 - lr: 0.0050
#
# Epoch 21: LearningRateScheduler setting learning rate to 0.004969223402440548.
# Epoch 21/400
# 43/43 [==============================] - 2s 44ms/step - loss: 0.0224 - custom_metric: 6.8030 - val_loss: 0.0041 - val_custom_metric: 0.8314 - lr: 0.0050
#
# Epoch 22: LearningRateScheduler setting learning rate to 0.004966075997799635.
# Epoch 22/400
# 43/43 [==============================] - 2s 44ms/step - loss: 0.0164 - custom_metric: 3.7979 - val_loss: 0.0048 - val_custom_metric: 2.4571 - lr: 0.0050
#
# Epoch 23: LearningRateScheduler setting learning rate to 0.00496277678757906.
# Epoch 23/400
# 43/43 [==============================] - 2s 46ms/step - loss: 0.0219 - custom_metric: 4.6887 - val_loss: 0.0056 - val_custom_metric: 1.8467 - lr: 0.0050
#
# Epoch 24: LearningRateScheduler setting learning rate to 0.004959325771778822.
# Epoch 24/400
# 43/43 [==============================] - 2s 44ms/step - loss: 0.0133 - custom_metric: 3.0470 - val_loss: 0.0044 - val_custom_metric: 0.8780 - lr: 0.0050
#
# Epoch 25: LearningRateScheduler setting learning rate to 0.004955722484737635.
# Epoch 25/400
# 43/43 [==============================] - 2s 44ms/step - loss: 0.0102 - custom_metric: 2.0696 - val_loss: 0.0052 - val_custom_metric: 0.7913 - lr: 0.0050
#
# Epoch 26: LearningRateScheduler setting learning rate to 0.004951967857778072.
# Epoch 26/400
# 43/43 [==============================] - 2s 46ms/step - loss: 0.0117 - custom_metric: 3.5906 - val_loss: 0.0049 - val_custom_metric: 0.8947 - lr: 0.0050
#
# Epoch 27: LearningRateScheduler setting learning rate to 0.004948061890900135.
# Epoch 27/400
# 43/43 [==============================] - 2s 44ms/step - loss: 0.0111 - custom_metric: 2.6679 - val_loss: 0.0055 - val_custom_metric: 0.8185 - lr: 0.0049
#
# Epoch 28: LearningRateScheduler setting learning rate to 0.00494400504976511.
# Epoch 28/400
# 43/43 [==============================] - 2s 44ms/step - loss: 0.0144 - custom_metric: 2.2983 - val_loss: 0.0053 - val_custom_metric: 1.0787 - lr: 0.0049
#
# Epoch 29: LearningRateScheduler setting learning rate to 0.004939797800034285.
# Epoch 29/400
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0132 - custom_metric: 3.5785 - val_loss: 0.0069 - val_custom_metric: 2.8892 - lr: 0.0049
#
# Epoch 30: LearningRateScheduler setting learning rate to 0.0049354396760463715.
# Epoch 30/400
# 43/43 [==============================] - 2s 43ms/step - loss: 0.0098 - custom_metric: 2.5306 - val_loss: 0.0058 - val_custom_metric: 2.8970 - lr: 0.0049
#
# Epoch 31: LearningRateScheduler setting learning rate to 0.004930931609123945.
# Epoch 31/400
# 43/43 [==============================] - 2s 44ms/step - loss: 0.0101 - custom_metric: 2.6040 - val_loss: 0.0048 - val_custom_metric: 1.3367 - lr: 0.0049
#
# Epoch 32: LearningRateScheduler setting learning rate to 0.004926273599267006.
# Epoch 32/400
# 43/43 [==============================] - 2s 44ms/step - loss: 0.0105 - custom_metric: 4.5123 - val_loss: 0.0044 - val_custom_metric: 0.8189 - lr: 0.0049
#
# Epoch 33: LearningRateScheduler setting learning rate to 0.004921465180814266.
# Epoch 33/400
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0096 - custom_metric: 1.9852 - val_loss: 0.0042 - val_custom_metric: 0.7762 - lr: 0.0049
#
# Epoch 34: LearningRateScheduler setting learning rate to 0.004916508682072163.
# Epoch 34/400
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0121 - custom_metric: 3.7978 - val_loss: 0.0049 - val_custom_metric: 1.8923 - lr: 0.0049
#
# Epoch 35: LearningRateScheduler setting learning rate to 0.004911402240395546.
# Epoch 35/400
# 43/43 [==============================] - 2s 44ms/step - loss: 0.0117 - custom_metric: 3.2665 - val_loss: 0.0042 - val_custom_metric: 0.6494 - lr: 0.0049
#
# Epoch 36: LearningRateScheduler setting learning rate to 0.004906147718429565.
# Epoch 36/400
# 43/43 [==============================] - 2s 44ms/step - loss: 0.0102 - custom_metric: 1.8141 - val_loss: 0.0044 - val_custom_metric: 1.1629 - lr: 0.0049
#
# Epoch 37: LearningRateScheduler setting learning rate to 0.004900744184851646.
# Epoch 37/400
# 43/43 [==============================] - 2s 44ms/step - loss: 0.0101 - custom_metric: 2.1788 - val_loss: 0.0037 - val_custom_metric: 0.6517 - lr: 0.0049
#
# Epoch 38: LearningRateScheduler setting learning rate to 0.0048951925709843636.
# Epoch 38/400
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0093 - custom_metric: 1.9196 - val_loss: 0.0038 - val_custom_metric: 0.9733 - lr: 0.0049
#
# Epoch 39: LearningRateScheduler setting learning rate to 0.004889493342489004.
# Epoch 39/400
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0108 - custom_metric: 1.6152 - val_loss: 0.0040 - val_custom_metric: 0.5895 - lr: 0.0049
#
# Epoch 40: LearningRateScheduler setting learning rate to 0.0048836469650268555.
# Epoch 40/400
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0094 - custom_metric: 1.9400 - val_loss: 0.0040 - val_custom_metric: 0.7462 - lr: 0.0049
#
# Epoch 41: LearningRateScheduler setting learning rate to 0.0048776534385979176.
# Epoch 41/400
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0120 - custom_metric: 2.2177 - val_loss: 0.0044 - val_custom_metric: 0.9356 - lr: 0.0049
#
# Epoch 42: LearningRateScheduler setting learning rate to 0.004871513228863478.
# Epoch 42/400
# 43/43 [==============================] - 2s 44ms/step - loss: 0.0104 - custom_metric: 1.9219 - val_loss: 0.0043 - val_custom_metric: 0.9452 - lr: 0.0049
#
# Epoch 43: LearningRateScheduler setting learning rate to 0.004865226801484823.
# Epoch 43/400
# 43/43 [==============================] - 2s 44ms/step - loss: 0.0128 - custom_metric: 1.9109 - val_loss: 0.0046 - val_custom_metric: 0.7941 - lr: 0.0049
#
# Epoch 44: LearningRateScheduler setting learning rate to 0.004858794622123241.
# Epoch 44/400
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0097 - custom_metric: 2.0046 - val_loss: 0.0052 - val_custom_metric: 0.8781 - lr: 0.0049
#
# Epoch 45: LearningRateScheduler setting learning rate to 0.004852216690778732.
# Epoch 45/400
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0104 - custom_metric: 1.9332 - val_loss: 0.0046 - val_custom_metric: 1.1896 - lr: 0.0049
#
# Epoch 46: LearningRateScheduler setting learning rate to 0.0048454939387738705.
# Epoch 46/400
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0090 - custom_metric: 1.8235 - val_loss: 0.0040 - val_custom_metric: 0.8215 - lr: 0.0048
#
# Epoch 47: LearningRateScheduler setting learning rate to 0.004838626366108656.
# Epoch 47/400
# 43/43 [==============================] - 2s 44ms/step - loss: 0.0091 - custom_metric: 1.6292 - val_loss: 0.0042 - val_custom_metric: 0.8063 - lr: 0.0048
#
# Epoch 48: LearningRateScheduler setting learning rate to 0.004831614438444376.
# Epoch 48/400
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0095 - custom_metric: 2.0942 - val_loss: 0.0043 - val_custom_metric: 0.8417 - lr: 0.0048
#
# Epoch 49: LearningRateScheduler setting learning rate to 0.004824458621442318.
# Epoch 49/400
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0100 - custom_metric: 2.7859 - val_loss: 0.0043 - val_custom_metric: 0.6742 - lr: 0.0048
#
# Epoch 50: LearningRateScheduler setting learning rate to 0.004817159380763769.
# Epoch 50/400
# 43/43 [==============================] - 2s 44ms/step - loss: 0.0086 - custom_metric: 1.9441 - val_loss: 0.0039 - val_custom_metric: 0.6125 - lr: 0.0048
#
# Epoch 51: LearningRateScheduler setting learning rate to 0.0048097181133925915.
# Epoch 51/400
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0085 - custom_metric: 1.3855 - val_loss: 0.0043 - val_custom_metric: 0.6936 - lr: 0.0048
#
# Epoch 52: LearningRateScheduler setting learning rate to 0.004802133422344923.
# Epoch 52/400
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0083 - custom_metric: 1.3053 - val_loss: 0.0044 - val_custom_metric: 0.7039 - lr: 0.0048
#
# Epoch 53: LearningRateScheduler setting learning rate to 0.004794407170265913.
# Epoch 53/400
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0088 - custom_metric: 1.3951 - val_loss: 0.0047 - val_custom_metric: 1.1441 - lr: 0.0048
#
# Epoch 54: LearningRateScheduler setting learning rate to 0.0047865393571555614.
# Epoch 54/400
# 43/43 [==============================] - 2s 44ms/step - loss: 0.0087 - custom_metric: 1.5026 - val_loss: 0.0039 - val_custom_metric: 0.7712 - lr: 0.0048
#
# Epoch 55: LearningRateScheduler setting learning rate to 0.004778529983013868.
# Epoch 55/400
# 43/43 [==============================] - 2s 44ms/step - loss: 0.0087 - custom_metric: 1.4520 - val_loss: 0.0044 - val_custom_metric: 0.7536 - lr: 0.0048
#
# Epoch 56: LearningRateScheduler setting learning rate to 0.004770380910485983.
# Epoch 56/400
# 43/43 [==============================] - 2s 44ms/step - loss: 0.0099 - custom_metric: 1.8239 - val_loss: 0.0042 - val_custom_metric: 0.6838 - lr: 0.0048
#
# Epoch 57: LearningRateScheduler setting learning rate to 0.004762091673910618.
# Epoch 57/400
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0103 - custom_metric: 1.9135 - val_loss: 0.0045 - val_custom_metric: 1.0255 - lr: 0.0048
#
# Epoch 58: LearningRateScheduler setting learning rate to 0.0047536627389490604.
# Epoch 58/400
# 43/43 [==============================] - 2s 44ms/step - loss: 0.0095 - custom_metric: 1.5541 - val_loss: 0.0040 - val_custom_metric: 0.7487 - lr: 0.0048
#
# Epoch 59: LearningRateScheduler setting learning rate to 0.004745094571262598.
# Epoch 59/400
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0087 - custom_metric: 1.3652 - val_loss: 0.0043 - val_custom_metric: 0.7252 - lr: 0.0047
#
# Epoch 60: LearningRateScheduler setting learning rate to 0.004736387636512518.
# Epoch 60/400
# 43/43 [==============================] - 2s 48ms/step - loss: 0.0081 - custom_metric: 1.5131 - val_loss: 0.0044 - val_custom_metric: 0.8410 - lr: 0.0047
#
# Epoch 61: LearningRateScheduler setting learning rate to 0.004727543331682682.
# Epoch 61/400
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0083 - custom_metric: 1.4612 - val_loss: 0.0040 - val_custom_metric: 1.0228 - lr: 0.0047
#
# Epoch 62: LearningRateScheduler setting learning rate to 0.00471856165677309.
# Epoch 62/400
# 43/43 [==============================] - 2s 46ms/step - loss: 0.0088 - custom_metric: 2.0131 - val_loss: 0.0043 - val_custom_metric: 0.7314 - lr: 0.0047
#
# Epoch 63: LearningRateScheduler setting learning rate to 0.0047094435431063175.
# Epoch 63/400
# 43/43 [==============================] - 2s 46ms/step - loss: 0.0088 - custom_metric: 1.3760 - val_loss: 0.0042 - val_custom_metric: 0.7349 - lr: 0.0047
#
# Epoch 64: LearningRateScheduler setting learning rate to 0.004700188059359789.
# Epoch 64/400
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0080 - custom_metric: 1.3285 - val_loss: 0.0041 - val_custom_metric: 0.7145 - lr: 0.0047
#
# Epoch 65: LearningRateScheduler setting learning rate to 0.004690797999501228.
# Epoch 65/400
# 43/43 [==============================] - 2s 46ms/step - loss: 0.0083 - custom_metric: 1.4410 - val_loss: 0.0045 - val_custom_metric: 0.7534 - lr: 0.0047
#
# Epoch 66: LearningRateScheduler setting learning rate to 0.004681271966546774.
# Epoch 66/400
# 43/43 [==============================] - 2s 46ms/step - loss: 0.0099 - custom_metric: 1.7535 - val_loss: 0.0046 - val_custom_metric: 0.8704 - lr: 0.0047
#
# Epoch 67: LearningRateScheduler setting learning rate to 0.004671611823141575.
# Epoch 67/400
# 43/43 [==============================] - 2s 46ms/step - loss: 0.0087 - custom_metric: 1.3161 - val_loss: 0.0040 - val_custom_metric: 0.7547 - lr: 0.0047
#
# Epoch 68: LearningRateScheduler setting learning rate to 0.004661817569285631.
# Epoch 68/400
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0087 - custom_metric: 1.5564 - val_loss: 0.0040 - val_custom_metric: 0.6862 - lr: 0.0047
#
# Epoch 69: LearningRateScheduler setting learning rate to 0.0046518901363015175.
# Epoch 69/400
# 43/43 [==============================] - 2s 46ms/step - loss: 0.0082 - custom_metric: 1.3594 - val_loss: 0.0038 - val_custom_metric: 0.7309 - lr: 0.0047
#
# Epoch 70: LearningRateScheduler setting learning rate to 0.004641829524189234.
# Epoch 70/400
# 43/43 [==============================] - 2s 46ms/step - loss: 0.0099 - custom_metric: 1.5802 - val_loss: 0.0042 - val_custom_metric: 0.7269 - lr: 0.0046
#
# Epoch 71: LearningRateScheduler setting learning rate to 0.004631637129932642.
# Epoch 71/400
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0079 - custom_metric: 1.3447 - val_loss: 0.0044 - val_custom_metric: 0.7950 - lr: 0.0046
#
# Epoch 72: LearningRateScheduler setting learning rate to 0.004621313419193029.
# Epoch 72/400
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0082 - custom_metric: 1.4537 - val_loss: 0.0043 - val_custom_metric: 0.7048 - lr: 0.0046
#
# Epoch 73: LearningRateScheduler setting learning rate to 0.004610858857631683.
# Epoch 73/400
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0082 - custom_metric: 1.4934 - val_loss: 0.0038 - val_custom_metric: 0.6929 - lr: 0.0046
#
# Epoch 74: LearningRateScheduler setting learning rate to 0.004600273910909891.
# Epoch 74/400
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0076 - custom_metric: 1.1634 - val_loss: 0.0040 - val_custom_metric: 0.6556 - lr: 0.0046
#
# Epoch 75: LearningRateScheduler setting learning rate to 0.004589559510350227.
# Epoch 75/400
# 43/43 [==============================] - 2s 44ms/step - loss: 0.0078 - custom_metric: 1.1731 - val_loss: 0.0039 - val_custom_metric: 0.7035 - lr: 0.0046
#
# Epoch 76: LearningRateScheduler setting learning rate to 0.004578716121613979.
# Epoch 76/400
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0076 - custom_metric: 1.1634 - val_loss: 0.0042 - val_custom_metric: 0.6578 - lr: 0.0046
#
# Epoch 77: LearningRateScheduler setting learning rate to 0.004567744676023722.
# Epoch 77/400
# 43/43 [==============================] - 2s 44ms/step - loss: 0.0078 - custom_metric: 1.3038 - val_loss: 0.0040 - val_custom_metric: 0.6903 - lr: 0.0046
#
# Epoch 78: LearningRateScheduler setting learning rate to 0.004556645639240742.
# Epoch 78/400
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0080 - custom_metric: 1.2446 - val_loss: 0.0041 - val_custom_metric: 0.8178 - lr: 0.0046
#
# Epoch 79: LearningRateScheduler setting learning rate to 0.004545419942587614.
# Epoch 79/400
# 43/43 [==============================] - 2s 44ms/step - loss: 0.0078 - custom_metric: 1.3148 - val_loss: 0.0041 - val_custom_metric: 0.6625 - lr: 0.0045
#
# Epoch 80: LearningRateScheduler setting learning rate to 0.004534067586064339.
# Epoch 80/400
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0081 - custom_metric: 1.2265 - val_loss: 0.0041 - val_custom_metric: 0.8394 - lr: 0.0045
#
# Epoch 81: LearningRateScheduler setting learning rate to 0.0045225899666547775.
# Epoch 81/400
# 43/43 [==============================] - 2s 44ms/step - loss: 0.0078 - custom_metric: 1.2372 - val_loss: 0.0043 - val_custom_metric: 0.8377 - lr: 0.0045
#
# Epoch 82: LearningRateScheduler setting learning rate to 0.004510988015681505.
# Epoch 82/400
# 43/43 [==============================] - 2s 44ms/step - loss: 0.0084 - custom_metric: 1.2519 - val_loss: 0.0044 - val_custom_metric: 0.7527 - lr: 0.0045
#
# Epoch 83: LearningRateScheduler setting learning rate to 0.004499261733144522.
# Epoch 83/400
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0082 - custom_metric: 1.2292 - val_loss: 0.0039 - val_custom_metric: 0.6288 - lr: 0.0045
#
# Epoch 84: LearningRateScheduler setting learning rate to 0.004487412050366402.
# Epoch 84/400
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0077 - custom_metric: 1.2454 - val_loss: 0.0044 - val_custom_metric: 0.6550 - lr: 0.0045
#
# Epoch 85: LearningRateScheduler setting learning rate to 0.00447543989866972.
# Epoch 85/400
# 43/43 [==============================] - 2s 44ms/step - loss: 0.0073 - custom_metric: 1.1704 - val_loss: 0.0040 - val_custom_metric: 0.6810 - lr: 0.0045
#
# Epoch 86: LearningRateScheduler setting learning rate to 0.004463345743715763.
# Epoch 86/400
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0076 - custom_metric: 1.1576 - val_loss: 0.0040 - val_custom_metric: 0.7065 - lr: 0.0045
#
# Epoch 87: LearningRateScheduler setting learning rate to 0.004451130982488394.
# Epoch 87/400
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0074 - custom_metric: 1.1793 - val_loss: 0.0040 - val_custom_metric: 0.6732 - lr: 0.0045
#
# Epoch 88: LearningRateScheduler setting learning rate to 0.0044387951493263245.
# Epoch 88/400
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0072 - custom_metric: 1.0618 - val_loss: 0.0042 - val_custom_metric: 0.7950 - lr: 0.0044
#
# Epoch 89: LearningRateScheduler setting learning rate to 0.004426340572535992.
# Epoch 89/400
# 43/43 [==============================] - 2s 46ms/step - loss: 0.0079 - custom_metric: 1.1961 - val_loss: 0.0039 - val_custom_metric: 0.6128 - lr: 0.0044
#
# Epoch 90: LearningRateScheduler setting learning rate to 0.004413766786456108.
# Epoch 90/400
# 43/43 [==============================] - 2s 46ms/step - loss: 0.0073 - custom_metric: 1.1696 - val_loss: 0.0040 - val_custom_metric: 0.6759 - lr: 0.0044
#
# Epoch 91: LearningRateScheduler setting learning rate to 0.004401074722409248.
# Epoch 91/400
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0074 - custom_metric: 1.0991 - val_loss: 0.0044 - val_custom_metric: 0.7823 - lr: 0.0044
#
# Epoch 92: LearningRateScheduler setting learning rate to 0.004388265777379274.
# Epoch 92/400
# 43/43 [==============================] - 2s 46ms/step - loss: 0.0073 - custom_metric: 1.1355 - val_loss: 0.0042 - val_custom_metric: 0.6121 - lr: 0.0044
#
# Epoch 93: LearningRateScheduler setting learning rate to 0.0043753404170274734.
# Epoch 93/400
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0075 - custom_metric: 1.1572 - val_loss: 0.0042 - val_custom_metric: 0.6713 - lr: 0.0044
#
# Epoch 94: LearningRateScheduler setting learning rate to 0.004362298641353846.
# Epoch 94/400
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0072 - custom_metric: 1.0920 - val_loss: 0.0040 - val_custom_metric: 0.6754 - lr: 0.0044
#
# Epoch 95: LearningRateScheduler setting learning rate to 0.004349142778664827.
# Epoch 95/400
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0074 - custom_metric: 1.0962 - val_loss: 0.0040 - val_custom_metric: 0.6556 - lr: 0.0043
#
# Epoch 96: LearningRateScheduler setting learning rate to 0.004335872828960419.
# Epoch 96/400
# 43/43 [==============================] - 2s 46ms/step - loss: 0.0074 - custom_metric: 1.1028 - val_loss: 0.0042 - val_custom_metric: 0.7512 - lr: 0.0043
#
# Epoch 97: LearningRateScheduler setting learning rate to 0.004322489257901907.
# Epoch 97/400
# 43/43 [==============================] - 2s 46ms/step - loss: 0.0074 - custom_metric: 1.1341 - val_loss: 0.0043 - val_custom_metric: 0.8563 - lr: 0.0043
#
# Epoch 98: LearningRateScheduler setting learning rate to 0.004308993928134441.
# Epoch 98/400
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0072 - custom_metric: 1.0416 - val_loss: 0.0043 - val_custom_metric: 0.6841 - lr: 0.0043
#
# Epoch 99: LearningRateScheduler setting learning rate to 0.004295385908335447.
# Epoch 99/400
# 43/43 [==============================] - 2s 46ms/step - loss: 0.0073 - custom_metric: 1.0673 - val_loss: 0.0043 - val_custom_metric: 0.7222 - lr: 0.0043
#
# Epoch 100: LearningRateScheduler setting learning rate to 0.004281668458133936.
# Epoch 100/400
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0072 - custom_metric: 1.0667 - val_loss: 0.0041 - val_custom_metric: 0.6657 - lr: 0.0043
#
# Epoch 101: LearningRateScheduler setting learning rate to 0.004267840180546045.
# Epoch 101/400
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0071 - custom_metric: 1.0777 - val_loss: 0.0043 - val_custom_metric: 0.6970 - lr: 0.0043
#
# Epoch 102: LearningRateScheduler setting learning rate to 0.004253902938216925.
# Epoch 102/400
# 43/43 [==============================] - 2s 46ms/step - loss: 0.0072 - custom_metric: 1.0890 - val_loss: 0.0041 - val_custom_metric: 0.6167 - lr: 0.0043
#
# Epoch 103: LearningRateScheduler setting learning rate to 0.004239858128130436.
# Epoch 103/400
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0071 - custom_metric: 1.0491 - val_loss: 0.0040 - val_custom_metric: 0.6298 - lr: 0.0042
#
# Epoch 104: LearningRateScheduler setting learning rate to 0.004225705284625292.
# Epoch 104/400
# 43/43 [==============================] - 2s 44ms/step - loss: 0.0071 - custom_metric: 1.0435 - val_loss: 0.0050 - val_custom_metric: 0.7616 - lr: 0.0042
#
# Epoch 105: LearningRateScheduler setting learning rate to 0.004211446736007929.
# Epoch 105/400
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0069 - custom_metric: 1.0030 - val_loss: 0.0038 - val_custom_metric: 0.5915 - lr: 0.0042
#
# Epoch 106: LearningRateScheduler setting learning rate to 0.00419708201661706.
# Epoch 106/400
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0070 - custom_metric: 1.0348 - val_loss: 0.0049 - val_custom_metric: 0.7299 - lr: 0.0042
#
# Epoch 107: LearningRateScheduler setting learning rate to 0.004182612989097834.
# Epoch 107/400
# 43/43 [==============================] - 2s 46ms/step - loss: 0.0069 - custom_metric: 1.0333 - val_loss: 0.0043 - val_custom_metric: 0.6570 - lr: 0.0042
#
# Epoch 108: LearningRateScheduler setting learning rate to 0.004168040119111538.
# Epoch 108/400
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0067 - custom_metric: 0.9743 - val_loss: 0.0040 - val_custom_metric: 0.6392 - lr: 0.0042
#
# Epoch 109: LearningRateScheduler setting learning rate to 0.004153364337980747.
# Epoch 109/400
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0070 - custom_metric: 1.0081 - val_loss: 0.0043 - val_custom_metric: 0.6843 - lr: 0.0042
#
# Epoch 110: LearningRateScheduler setting learning rate to 0.004138586577028036.
# Epoch 110/400
# 43/43 [==============================] - 2s 46ms/step - loss: 0.0070 - custom_metric: 1.0037 - val_loss: 0.0044 - val_custom_metric: 0.6736 - lr: 0.0041
#
# Epoch 111: LearningRateScheduler setting learning rate to 0.004123707767575979.
# Epoch 111/400
# 43/43 [==============================] - 2s 44ms/step - loss: 0.0069 - custom_metric: 1.0027 - val_loss: 0.0043 - val_custom_metric: 0.7357 - lr: 0.0041
#
# Epoch 112: LearningRateScheduler setting learning rate to 0.004108728840947151.
# Epoch 112/400
# 43/43 [==============================] - 2s 46ms/step - loss: 0.0069 - custom_metric: 1.0365 - val_loss: 0.0049 - val_custom_metric: 0.7762 - lr: 0.0041
#
# Epoch 113: LearningRateScheduler setting learning rate to 0.004093650262802839.
# Epoch 113/400
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0069 - custom_metric: 1.0179 - val_loss: 0.0046 - val_custom_metric: 0.6845 - lr: 0.0041
#
# Epoch 114: LearningRateScheduler setting learning rate to 0.004078473895788193.
# Epoch 114/400
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0068 - custom_metric: 0.9876 - val_loss: 0.0044 - val_custom_metric: 0.6420 - lr: 0.0041
#
# Epoch 115: LearningRateScheduler setting learning rate to 0.004063200205564499.
# Epoch 115/400
# 43/43 [==============================] - 2s 46ms/step - loss: 0.0068 - custom_metric: 1.0056 - val_loss: 0.0042 - val_custom_metric: 0.6885 - lr: 0.0041
#
# Epoch 116: LearningRateScheduler setting learning rate to 0.004047830123454332.
# Epoch 116/400
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0068 - custom_metric: 0.9750 - val_loss: 0.0040 - val_custom_metric: 0.6761 - lr: 0.0040
#
# Epoch 117: LearningRateScheduler setting learning rate to 0.004032364580780268.
# Epoch 117/400
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0068 - custom_metric: 0.9797 - val_loss: 0.0039 - val_custom_metric: 0.5876 - lr: 0.0040
#
# Epoch 118: LearningRateScheduler setting learning rate to 0.004016804043203592.
# Epoch 118/400
# 43/43 [==============================] - 2s 46ms/step - loss: 0.0067 - custom_metric: 0.9703 - val_loss: 0.0039 - val_custom_metric: 0.6044 - lr: 0.0040
#
# Epoch 119: LearningRateScheduler setting learning rate to 0.004001150373369455.
# Epoch 119/400
# 43/43 [==============================] - 2s 46ms/step - loss: 0.0068 - custom_metric: 0.9698 - val_loss: 0.0038 - val_custom_metric: 0.6219 - lr: 0.0040
#
# Epoch 120: LearningRateScheduler setting learning rate to 0.003985404036939144.
# Epoch 120/400
# 43/43 [==============================] - 2s 46ms/step - loss: 0.0068 - custom_metric: 1.0252 - val_loss: 0.0039 - val_custom_metric: 0.6677 - lr: 0.0040
#
# Epoch 121: LearningRateScheduler setting learning rate to 0.003969565965235233.
# Epoch 121/400
# 43/43 [==============================] - 2s 46ms/step - loss: 0.0067 - custom_metric: 0.9883 - val_loss: 0.0042 - val_custom_metric: 0.6370 - lr: 0.0040
#
# Epoch 122: LearningRateScheduler setting learning rate to 0.003953637555241585.
# Epoch 122/400
# 43/43 [==============================] - 2s 46ms/step - loss: 0.0068 - custom_metric: 0.9750 - val_loss: 0.0039 - val_custom_metric: 0.5960 - lr: 0.0040
#
# Epoch 123: LearningRateScheduler setting learning rate to 0.003937619738280773.
# Epoch 123/400
# 43/43 [==============================] - 2s 46ms/step - loss: 0.0067 - custom_metric: 0.9562 - val_loss: 0.0039 - val_custom_metric: 0.6170 - lr: 0.0039
#
# Epoch 124: LearningRateScheduler setting learning rate to 0.003921512048691511.
# Epoch 124/400
# 43/43 [==============================] - 2s 47ms/step - loss: 0.0066 - custom_metric: 0.9468 - val_loss: 0.0041 - val_custom_metric: 0.6471 - lr: 0.0039
#
# Epoch 125: LearningRateScheduler setting learning rate to 0.00390531774610281.
# Epoch 125/400
# 43/43 [==============================] - 2s 46ms/step - loss: 0.0066 - custom_metric: 0.9525 - val_loss: 0.0039 - val_custom_metric: 0.6175 - lr: 0.0039
#
# Epoch 126: LearningRateScheduler setting learning rate to 0.0038890365976840258.
# Epoch 126/400
# 43/43 [==============================] - 2s 47ms/step - loss: 0.0066 - custom_metric: 0.9467 - val_loss: 0.0035 - val_custom_metric: 0.6071 - lr: 0.0039
#
# Epoch 127: LearningRateScheduler setting learning rate to 0.0038726695347577333.
# Epoch 127/400
# 43/43 [==============================] - 2s 46ms/step - loss: 0.0067 - custom_metric: 0.9525 - val_loss: 0.0039 - val_custom_metric: 0.6062 - lr: 0.0039
#
# Epoch 128: LearningRateScheduler setting learning rate to 0.003856218419969082.
# Epoch 128/400
# 43/43 [==============================] - 2s 47ms/step - loss: 0.0067 - custom_metric: 0.9599 - val_loss: 0.0041 - val_custom_metric: 0.6319 - lr: 0.0039
#
# Epoch 129: LearningRateScheduler setting learning rate to 0.0038396825548261404.
# Epoch 129/400
# 43/43 [==============================] - 2s 46ms/step - loss: 0.0066 - custom_metric: 0.9424 - val_loss: 0.0039 - val_custom_metric: 0.6547 - lr: 0.0038
#
# Epoch 130: LearningRateScheduler setting learning rate to 0.0038230647332966328.
# Epoch 130/400
# 43/43 [==============================] - 2s 46ms/step - loss: 0.0067 - custom_metric: 0.9623 - val_loss: 0.0042 - val_custom_metric: 0.6713 - lr: 0.0038
#
# Epoch 131: LearningRateScheduler setting learning rate to 0.00380636565387249.
# Epoch 131/400
# 43/43 [==============================] - 2s 46ms/step - loss: 0.0066 - custom_metric: 0.9509 - val_loss: 0.0039 - val_custom_metric: 0.6500 - lr: 0.0038
#
# Epoch 132: LearningRateScheduler setting learning rate to 0.003789585782214999.
# Epoch 132/400
# 43/43 [==============================] - 2s 46ms/step - loss: 0.0066 - custom_metric: 0.9611 - val_loss: 0.0049 - val_custom_metric: 0.6895 - lr: 0.0038
#
# Epoch 133: LearningRateScheduler setting learning rate to 0.003772726282477379.
# Epoch 133/400
# 43/43 [==============================] - 2s 46ms/step - loss: 0.0072 - custom_metric: 1.0308 - val_loss: 0.0043 - val_custom_metric: 0.6730 - lr: 0.0038
#
# Epoch 134: LearningRateScheduler setting learning rate to 0.003755788318812847.
# Epoch 134/400
# 43/43 [==============================] - 2s 46ms/step - loss: 0.0071 - custom_metric: 1.0177 - val_loss: 0.0039 - val_custom_metric: 0.6668 - lr: 0.0038
#
# Epoch 135: LearningRateScheduler setting learning rate to 0.0037387728225439787.
# Epoch 135/400
# 43/43 [==============================] - 2s 46ms/step - loss: 0.0071 - custom_metric: 1.0104 - val_loss: 0.0044 - val_custom_metric: 0.6906 - lr: 0.0037
#
# Epoch 136: LearningRateScheduler setting learning rate to 0.0037216809578239918.
# Epoch 136/400
# 43/43 [==============================] - 2s 44ms/step - loss: 0.0071 - custom_metric: 0.9993 - val_loss: 0.0042 - val_custom_metric: 0.6915 - lr: 0.0037
#
# Epoch 137: LearningRateScheduler setting learning rate to 0.0037045138888061047.
# Epoch 137/400
# 43/43 [==============================] - 2s 46ms/step - loss: 0.0069 - custom_metric: 0.9846 - val_loss: 0.0041 - val_custom_metric: 0.6356 - lr: 0.0037
#
# Epoch 138: LearningRateScheduler setting learning rate to 0.0036872723139822483.
# Epoch 138/400
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0069 - custom_metric: 0.9778 - val_loss: 0.0041 - val_custom_metric: 0.6155 - lr: 0.0037
#
# Epoch 139: LearningRateScheduler setting learning rate to 0.003669957397505641.
# Epoch 139/400
# 43/43 [==============================] - 2s 46ms/step - loss: 0.0069 - custom_metric: 0.9770 - val_loss: 0.0039 - val_custom_metric: 0.5987 - lr: 0.0037
#
# Epoch 140: LearningRateScheduler setting learning rate to 0.0036525707691907883.
# Epoch 140/400
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0069 - custom_metric: 0.9714 - val_loss: 0.0041 - val_custom_metric: 0.6195 - lr: 0.0037
#
# Epoch 141: LearningRateScheduler setting learning rate to 0.0036351128946989775.
# Epoch 141/400
# 43/43 [==============================] - 2s 46ms/step - loss: 0.0068 - custom_metric: 0.9581 - val_loss: 0.0039 - val_custom_metric: 0.5707 - lr: 0.0036
#
# Epoch 142: LearningRateScheduler setting learning rate to 0.003617584938183427.
# Epoch 142/400
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0068 - custom_metric: 0.9581 - val_loss: 0.0040 - val_custom_metric: 0.6951 - lr: 0.0036
#
# Epoch 143: LearningRateScheduler setting learning rate to 0.0035999880637973547.
# Epoch 143/400
# 43/43 [==============================] - 2s 46ms/step - loss: 0.0068 - custom_metric: 0.9704 - val_loss: 0.0041 - val_custom_metric: 0.6532 - lr: 0.0036
#
# Epoch 144: LearningRateScheduler setting learning rate to 0.0035823234356939793.
# Epoch 144/400
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0068 - custom_metric: 0.9670 - val_loss: 0.0039 - val_custom_metric: 0.5875 - lr: 0.0036
#
# Epoch 145: LearningRateScheduler setting learning rate to 0.003564591985195875.
# Epoch 145/400
# 43/43 [==============================] - 2s 46ms/step - loss: 0.0067 - custom_metric: 0.9510 - val_loss: 0.0042 - val_custom_metric: 0.5920 - lr: 0.0036
#
# Epoch 146: LearningRateScheduler setting learning rate to 0.0035467948764562607.
# Epoch 146/400
# 43/43 [==============================] - 2s 47ms/step - loss: 0.0066 - custom_metric: 0.9384 - val_loss: 0.0042 - val_custom_metric: 0.6174 - lr: 0.0035
#
# Epoch 147: LearningRateScheduler setting learning rate to 0.0035289330407977104.
# Epoch 147/400
# 43/43 [==============================] - 2s 48ms/step - loss: 0.0067 - custom_metric: 0.9439 - val_loss: 0.0040 - val_custom_metric: 0.5690 - lr: 0.0035
#
# Epoch 148: LearningRateScheduler setting learning rate to 0.0035110078752040863.
# Epoch 148/400
# 43/43 [==============================] - 2s 46ms/step - loss: 0.0066 - custom_metric: 0.9399 - val_loss: 0.0039 - val_custom_metric: 0.5852 - lr: 0.0035
#
# Epoch 149: LearningRateScheduler setting learning rate to 0.0034930205438286066.
# Epoch 149/400
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0067 - custom_metric: 0.9508 - val_loss: 0.0042 - val_custom_metric: 0.6079 - lr: 0.0035
#
# Epoch 150: LearningRateScheduler setting learning rate to 0.0034749715123325586.
# Epoch 150/400
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0064 - custom_metric: 0.9176 - val_loss: 0.0039 - val_custom_metric: 0.6158 - lr: 0.0035
#
# Epoch 151: LearningRateScheduler setting learning rate to 0.003456863109022379.
# Epoch 151/400
# 43/43 [==============================] - 2s 49ms/step - loss: 0.0065 - custom_metric: 0.9262 - val_loss: 0.0044 - val_custom_metric: 0.6608 - lr: 0.0035
#
# Epoch 152: LearningRateScheduler setting learning rate to 0.003438695101067424.
# Epoch 152/400
# 43/43 [==============================] - 3s 68ms/step - loss: 0.0065 - custom_metric: 0.9132 - val_loss: 0.0040 - val_custom_metric: 0.6320 - lr: 0.0034
#
# Epoch 153: LearningRateScheduler setting learning rate to 0.003420469118282199.
# Epoch 153/400
# 43/43 [==============================] - 2s 47ms/step - loss: 0.0065 - custom_metric: 0.9253 - val_loss: 0.0042 - val_custom_metric: 0.6446 - lr: 0.0034
#
# Epoch 154: LearningRateScheduler setting learning rate to 0.003402186557650566.
# Epoch 154/400
# 43/43 [==============================] - 2s 47ms/step - loss: 0.0065 - custom_metric: 0.9314 - val_loss: 0.0039 - val_custom_metric: 0.5947 - lr: 0.0034
#
# Epoch 155: LearningRateScheduler setting learning rate to 0.0033838485833257437.
# Epoch 155/400
# 43/43 [==============================] - 2s 46ms/step - loss: 0.0065 - custom_metric: 0.9335 - val_loss: 0.0040 - val_custom_metric: 0.6049 - lr: 0.0034
#
# Epoch 156: LearningRateScheduler setting learning rate to 0.0033654561266303062.
# Epoch 156/400
# 43/43 [==============================] - 2s 46ms/step - loss: 0.0065 - custom_metric: 0.9220 - val_loss: 0.0039 - val_custom_metric: 0.5943 - lr: 0.0034
#
# Epoch 157: LearningRateScheduler setting learning rate to 0.003347010351717472.
# Epoch 157/400
# 43/43 [==============================] - 2s 46ms/step - loss: 0.0065 - custom_metric: 0.9318 - val_loss: 0.0041 - val_custom_metric: 0.6439 - lr: 0.0033
#
# Epoch 158: LearningRateScheduler setting learning rate to 0.003328511957079172.
# Epoch 158/400
# 43/43 [==============================] - 2s 47ms/step - loss: 0.0065 - custom_metric: 0.9202 - val_loss: 0.0040 - val_custom_metric: 0.6433 - lr: 0.0033
#
# Epoch 159: LearningRateScheduler setting learning rate to 0.0033099623396992683.
# Epoch 159/400
# 43/43 [==============================] - 2s 46ms/step - loss: 0.0064 - custom_metric: 0.9064 - val_loss: 0.0040 - val_custom_metric: 0.6199 - lr: 0.0033
#
# Epoch 160: LearningRateScheduler setting learning rate to 0.0032913631293922663.
# Epoch 160/400
# 43/43 [==============================] - 2s 46ms/step - loss: 0.0065 - custom_metric: 0.9215 - val_loss: 0.0043 - val_custom_metric: 0.6631 - lr: 0.0033
#
# Epoch 161: LearningRateScheduler setting learning rate to 0.003272715024650097.
# Epoch 161/400
# 43/43 [==============================] - 2s 47ms/step - loss: 0.0064 - custom_metric: 0.9152 - val_loss: 0.0045 - val_custom_metric: 0.6767 - lr: 0.0033
#
# Epoch 162: LearningRateScheduler setting learning rate to 0.0032540196552872658.
# Epoch 162/400
# 43/43 [==============================] - 2s 47ms/step - loss: 0.0065 - custom_metric: 0.9431 - val_loss: 0.0044 - val_custom_metric: 0.6551 - lr: 0.0033
#
# Epoch 163: LearningRateScheduler setting learning rate to 0.0032352772541344166.
# Epoch 163/400
# 43/43 [==============================] - 2s 48ms/step - loss: 0.0063 - custom_metric: 0.9022 - val_loss: 0.0041 - val_custom_metric: 0.6725 - lr: 0.0032
#
# Epoch 164: LearningRateScheduler setting learning rate to 0.0032164896838366985.
# Epoch 164/400
# 43/43 [==============================] - 2s 47ms/step - loss: 0.0065 - custom_metric: 0.9138 - val_loss: 0.0041 - val_custom_metric: 0.6409 - lr: 0.0032
#
# Epoch 165: LearningRateScheduler setting learning rate to 0.0031976578757166862.
# Epoch 165/400
# 43/43 [==============================] - 2s 47ms/step - loss: 0.0065 - custom_metric: 0.9287 - val_loss: 0.0038 - val_custom_metric: 0.5919 - lr: 0.0032
#
# Epoch 166: LearningRateScheduler setting learning rate to 0.003178782993927598.
# Epoch 166/400
# 43/43 [==============================] - 2s 47ms/step - loss: 0.0065 - custom_metric: 0.9197 - val_loss: 0.0040 - val_custom_metric: 0.6319 - lr: 0.0032
#
# Epoch 167: LearningRateScheduler setting learning rate to 0.0031598666682839394.
# Epoch 167/400
# 43/43 [==============================] - 2s 47ms/step - loss: 0.0064 - custom_metric: 0.9134 - val_loss: 0.0044 - val_custom_metric: 0.6500 - lr: 0.0032
#
# Epoch 168: LearningRateScheduler setting learning rate to 0.0031409093644469976.
# Epoch 168/400
# 43/43 [==============================] - 2s 47ms/step - loss: 0.0064 - custom_metric: 0.9172 - val_loss: 0.0050 - val_custom_metric: 0.7382 - lr: 0.0031
#
# Epoch 169: LearningRateScheduler setting learning rate to 0.0031219127122312784.
# Epoch 169/400
# 43/43 [==============================] - 2s 47ms/step - loss: 0.0064 - custom_metric: 0.9095 - val_loss: 0.0041 - val_custom_metric: 0.6171 - lr: 0.0031
#
# Epoch 170: LearningRateScheduler setting learning rate to 0.0031028776429593563.
# Epoch 170/400
# 43/43 [==============================] - 2s 47ms/step - loss: 0.0064 - custom_metric: 0.9132 - val_loss: 0.0044 - val_custom_metric: 0.6804 - lr: 0.0031
#
# Epoch 171: LearningRateScheduler setting learning rate to 0.003083805087953806.
# Epoch 171/400
# 43/43 [==============================] - 2s 48ms/step - loss: 0.0063 - custom_metric: 0.8952 - val_loss: 0.0040 - val_custom_metric: 0.6189 - lr: 0.0031
#
# Epoch 172: LearningRateScheduler setting learning rate to 0.0030646969098597765.
# Epoch 172/400
# 43/43 [==============================] - 2s 47ms/step - loss: 0.0062 - custom_metric: 0.8954 - val_loss: 0.0052 - val_custom_metric: 0.7787 - lr: 0.0031
#
# Epoch 173: LearningRateScheduler setting learning rate to 0.0030455535743385553.
# Epoch 173/400
# 43/43 [==============================] - 2s 47ms/step - loss: 0.0063 - custom_metric: 0.8992 - val_loss: 0.0041 - val_custom_metric: 0.6014 - lr: 0.0030
#
# Epoch 174: LearningRateScheduler setting learning rate to 0.003026376711204648.
# Epoch 174/400
# 43/43 [==============================] - 2s 46ms/step - loss: 0.0063 - custom_metric: 0.8923 - val_loss: 0.0040 - val_custom_metric: 0.5955 - lr: 0.0030
#
# Epoch 175: LearningRateScheduler setting learning rate to 0.0030071677174419165.
# Epoch 175/400
# 43/43 [==============================] - 2s 47ms/step - loss: 0.0063 - custom_metric: 0.8993 - val_loss: 0.0043 - val_custom_metric: 0.6067 - lr: 0.0030
#
# Epoch 176: LearningRateScheduler setting learning rate to 0.0029879268258810043.
# Epoch 176/400
# 43/43 [==============================] - 2s 46ms/step - loss: 0.0064 - custom_metric: 0.9038 - val_loss: 0.0041 - val_custom_metric: 0.6167 - lr: 0.0030
#
# Epoch 177: LearningRateScheduler setting learning rate to 0.002968656597658992.
# Epoch 177/400
# 43/43 [==============================] - 2s 46ms/step - loss: 0.0064 - custom_metric: 0.9027 - val_loss: 0.0043 - val_custom_metric: 0.6470 - lr: 0.0030
#
# Epoch 178: LearningRateScheduler setting learning rate to 0.002949357032775879.
# Epoch 178/400
# 43/43 [==============================] - 2s 46ms/step - loss: 0.0064 - custom_metric: 0.9191 - val_loss: 0.0046 - val_custom_metric: 0.6886 - lr: 0.0029
#
# Epoch 179: LearningRateScheduler setting learning rate to 0.002930029761046171.
# Epoch 179/400
# 43/43 [==============================] - 2s 47ms/step - loss: 0.0065 - custom_metric: 0.9235 - val_loss: 0.0039 - val_custom_metric: 0.6029 - lr: 0.0029
#
# Epoch 180: LearningRateScheduler setting learning rate to 0.002910675946623087.
# Epoch 180/400
# 43/43 [==============================] - 2s 46ms/step - loss: 0.0064 - custom_metric: 0.9077 - val_loss: 0.0042 - val_custom_metric: 0.6555 - lr: 0.0029
#
# Epoch 181: LearningRateScheduler setting learning rate to 0.0028912972193211317.
# Epoch 181/400
# 43/43 [==============================] - 2s 46ms/step - loss: 0.0063 - custom_metric: 0.9083 - val_loss: 0.0040 - val_custom_metric: 0.6111 - lr: 0.0029
#
# Epoch 182: LearningRateScheduler setting learning rate to 0.002871893811970949.
# Epoch 182/400
# 43/43 [==============================] - 2s 46ms/step - loss: 0.0065 - custom_metric: 0.9202 - val_loss: 0.0041 - val_custom_metric: 0.6261 - lr: 0.0029
#
# Epoch 183: LearningRateScheduler setting learning rate to 0.002852467820048332.
# Epoch 183/400
# 43/43 [==============================] - 2s 47ms/step - loss: 0.0065 - custom_metric: 0.9172 - val_loss: 0.0044 - val_custom_metric: 0.7256 - lr: 0.0029
#
# Epoch 184: LearningRateScheduler setting learning rate to 0.002833019942045212.
# Epoch 184/400
# 43/43 [==============================] - 2s 46ms/step - loss: 0.0065 - custom_metric: 0.9212 - val_loss: 0.0043 - val_custom_metric: 0.6292 - lr: 0.0028
#
# Epoch 185: LearningRateScheduler setting learning rate to 0.00281355157494545.
# Epoch 185/400
# 43/43 [==============================] - 2s 47ms/step - loss: 0.0064 - custom_metric: 0.9042 - val_loss: 0.0042 - val_custom_metric: 0.6628 - lr: 0.0028
#
# Epoch 186: LearningRateScheduler setting learning rate to 0.0027940638829022646.
# Epoch 186/400
# 43/43 [==============================] - 2s 47ms/step - loss: 0.0062 - custom_metric: 0.8863 - val_loss: 0.0044 - val_custom_metric: 0.6614 - lr: 0.0028
#
# Epoch 187: LearningRateScheduler setting learning rate to 0.002774558262899518.
# Epoch 187/400
# 43/43 [==============================] - 2s 47ms/step - loss: 0.0064 - custom_metric: 0.9140 - val_loss: 0.0052 - val_custom_metric: 0.7600 - lr: 0.0028
#
# Epoch 188: LearningRateScheduler setting learning rate to 0.002755035413429141.
# Epoch 188/400
# 43/43 [==============================] - 2s 47ms/step - loss: 0.0064 - custom_metric: 0.9110 - val_loss: 0.0041 - val_custom_metric: 0.6653 - lr: 0.0028
#
# Epoch 189: LearningRateScheduler setting learning rate to 0.002735497197136283.
# Epoch 189/400
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0063 - custom_metric: 0.8960 - val_loss: 0.0040 - val_custom_metric: 0.6163 - lr: 0.0027
#
# Epoch 190: LearningRateScheduler setting learning rate to 0.0027159443125128746.
# Epoch 190/400
# 43/43 [==============================] - 2s 48ms/step - loss: 0.0063 - custom_metric: 0.8889 - val_loss: 0.0041 - val_custom_metric: 0.6356 - lr: 0.0027
#
# Epoch 191: LearningRateScheduler setting learning rate to 0.0026963779237121344.
# Epoch 191/400
# 43/43 [==============================] - 2s 47ms/step - loss: 0.0064 - custom_metric: 0.9007 - val_loss: 0.0041 - val_custom_metric: 0.6379 - lr: 0.0027
#
# Epoch 192: LearningRateScheduler setting learning rate to 0.0026767998933792114.
# Epoch 192/400
# 43/43 [==============================] - 2s 46ms/step - loss: 0.0063 - custom_metric: 0.8911 - val_loss: 0.0038 - val_custom_metric: 0.6152 - lr: 0.0027
#
# Epoch 193: LearningRateScheduler setting learning rate to 0.0026572104543447495.
# Epoch 193/400
# 43/43 [==============================] - 2s 47ms/step - loss: 0.0062 - custom_metric: 0.8874 - val_loss: 0.0040 - val_custom_metric: 0.6357 - lr: 0.0027
#
# Epoch 194: LearningRateScheduler setting learning rate to 0.0026376114692538977.
# Epoch 194/400
# 43/43 [==============================] - 2s 47ms/step - loss: 0.0062 - custom_metric: 0.8965 - val_loss: 0.0036 - val_custom_metric: 0.5630 - lr: 0.0026
#
# ...
#
# Epoch 338: LearningRateScheduler setting learning rate to 0.0003003119200002402.
# Epoch 338/400
# 43/43 [==============================] - 2s 46ms/step - loss: 0.0051 - custom_metric: 0.7484 - val_loss: 0.0042 - val_custom_metric: 0.6193 - lr: 3.0031e-04
#
# Epoch 339: LearningRateScheduler setting learning rate to 0.00029105698922649026.
# Epoch 339/400
# 43/43 [==============================] - 2s 47ms/step - loss: 0.0051 - custom_metric: 0.7491 - val_loss: 0.0040 - val_custom_metric: 0.6105 - lr: 2.9106e-04
#
# Epoch 340: LearningRateScheduler setting learning rate to 0.0002819384098984301.
# Epoch 340/400
# 43/43 [==============================] - 2s 47ms/step - loss: 0.0051 - custom_metric: 0.7535 - val_loss: 0.0040 - val_custom_metric: 0.6036 - lr: 2.8194e-04
#
# Epoch 341: LearningRateScheduler setting learning rate to 0.00027295658946968615.
# Epoch 341/400
# 43/43 [==============================] - 2s 46ms/step - loss: 0.0051 - custom_metric: 0.7517 - val_loss: 0.0040 - val_custom_metric: 0.6063 - lr: 2.7296e-04
#
# Epoch 342: LearningRateScheduler setting learning rate to 0.0002641121100168675.
# Epoch 342/400
# 43/43 [==============================] - 2s 48ms/step - loss: 0.0051 - custom_metric: 0.7467 - val_loss: 0.0038 - val_custom_metric: 0.5879 - lr: 2.6411e-04
#
# Epoch 343: LearningRateScheduler setting learning rate to 0.0002554056409280747.
# Epoch 343/400
# 43/43 [==============================] - 2s 48ms/step - loss: 0.0051 - custom_metric: 0.7528 - val_loss: 0.0039 - val_custom_metric: 0.6030 - lr: 2.5541e-04
#
# Epoch 344: LearningRateScheduler setting learning rate to 0.00024683758965693414.
# Epoch 344/400
# 43/43 [==============================] - 2s 46ms/step - loss: 0.0050 - custom_metric: 0.7392 - val_loss: 0.0038 - val_custom_metric: 0.5857 - lr: 2.4684e-04
#
# Epoch 345: LearningRateScheduler setting learning rate to 0.00023840869835112244.
# Epoch 345/400
# 43/43 [==============================] - 2s 46ms/step - loss: 0.0051 - custom_metric: 0.7465 - val_loss: 0.0039 - val_custom_metric: 0.5993 - lr: 2.3841e-04
#
# Epoch 346: LearningRateScheduler setting learning rate to 0.00023011912708170712.
# Epoch 346/400
# 43/43 [==============================] - 2s 47ms/step - loss: 0.0051 - custom_metric: 0.7428 - val_loss: 0.0038 - val_custom_metric: 0.5839 - lr: 2.3012e-04
#
# Epoch 347: LearningRateScheduler setting learning rate to 0.00022196976351551712.
# Epoch 347/400
# 43/43 [==============================] - 2s 47ms/step - loss: 0.0051 - custom_metric: 0.7391 - val_loss: 0.0040 - val_custom_metric: 0.6108 - lr: 2.2197e-04
#
# Epoch 348: LearningRateScheduler setting learning rate to 0.00021396088413894176.
# Epoch 348/400
# 43/43 [==============================] - 2s 46ms/step - loss: 0.0050 - custom_metric: 0.7391 - val_loss: 0.0037 - val_custom_metric: 0.5684 - lr: 2.1396e-04
#
# Epoch 349: LearningRateScheduler setting learning rate to 0.0002060929691651836.
# Epoch 349/400
# 43/43 [==============================] - 2s 47ms/step - loss: 0.0051 - custom_metric: 0.7465 - val_loss: 0.0039 - val_custom_metric: 0.5931 - lr: 2.0609e-04
#
# Epoch 350: LearningRateScheduler setting learning rate to 0.00019836658611893654.
# Epoch 350/400
# 43/43 [==============================] - 2s 46ms/step - loss: 0.0051 - custom_metric: 0.7481 - val_loss: 0.0038 - val_custom_metric: 0.5798 - lr: 1.9837e-04
#
# Epoch 351: LearningRateScheduler setting learning rate to 0.00019078220066148788.
# Epoch 351/400
# 43/43 [==============================] - 2s 47ms/step - loss: 0.0050 - custom_metric: 0.7343 - val_loss: 0.0040 - val_custom_metric: 0.6121 - lr: 1.9078e-04
#
# Epoch 352: LearningRateScheduler setting learning rate to 0.0001833402639022097.
# Epoch 352/400
# 43/43 [==============================] - 2s 47ms/step - loss: 0.0050 - custom_metric: 0.7393 - val_loss: 0.0040 - val_custom_metric: 0.6045 - lr: 1.8334e-04
#
# Epoch 353: LearningRateScheduler setting learning rate to 0.00017604121239855886.
# Epoch 353/400
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0050 - custom_metric: 0.7322 - val_loss: 0.0039 - val_custom_metric: 0.6017 - lr: 1.7604e-04
#
# Epoch 354: LearningRateScheduler setting learning rate to 0.00016888565733097494.
# Epoch 354/400
# 43/43 [==============================] - 2s 47ms/step - loss: 0.0050 - custom_metric: 0.7312 - val_loss: 0.0041 - val_custom_metric: 0.6240 - lr: 1.6889e-04
#
# Epoch 355: LearningRateScheduler setting learning rate to 0.00016187386063393205.
# Epoch 355/400
# 43/43 [==============================] - 2s 46ms/step - loss: 0.0050 - custom_metric: 0.7365 - val_loss: 0.0037 - val_custom_metric: 0.5678 - lr: 1.6187e-04
#
# Epoch 356: LearningRateScheduler setting learning rate to 0.00015500630252063274.
# Epoch 356/400
# 43/43 [==============================] - 2s 47ms/step - loss: 0.0051 - custom_metric: 0.7420 - val_loss: 0.0040 - val_custom_metric: 0.6051 - lr: 1.5501e-04
#
# Epoch 357: LearningRateScheduler setting learning rate to 0.00014828327402938157.
# Epoch 357/400
# 43/43 [==============================] - 2s 47ms/step - loss: 0.0050 - custom_metric: 0.7333 - val_loss: 0.0039 - val_custom_metric: 0.6044 - lr: 1.4828e-04
#
# Epoch 358: LearningRateScheduler setting learning rate to 0.0001417055173078552.
# Epoch 358/400
# 43/43 [==============================] - 2s 47ms/step - loss: 0.0050 - custom_metric: 0.7349 - val_loss: 0.0037 - val_custom_metric: 0.5752 - lr: 1.4171e-04
#
# Epoch 359: LearningRateScheduler setting learning rate to 0.00013527317787520587.
# Epoch 359/400
# 43/43 [==============================] - 2s 47ms/step - loss: 0.0050 - custom_metric: 0.7330 - val_loss: 0.0039 - val_custom_metric: 0.5879 - lr: 1.3527e-04
#
# Epoch 360: LearningRateScheduler setting learning rate to 0.0001289867068408057.
# Epoch 360/400
# 43/43 [==============================] - 2s 47ms/step - loss: 0.0050 - custom_metric: 0.7322 - val_loss: 0.0039 - val_custom_metric: 0.5977 - lr: 1.2899e-04
#
# Epoch 361: LearningRateScheduler setting learning rate to 0.00012284655531402677.
# Epoch 361/400
# 43/43 [==============================] - 2s 49ms/step - loss: 0.0050 - custom_metric: 0.7407 - val_loss: 0.0039 - val_custom_metric: 0.5926 - lr: 1.2285e-04
#
# Epoch 362: LearningRateScheduler setting learning rate to 0.00011685301433317363.
# Epoch 362/400
# 43/43 [==============================] - 2s 47ms/step - loss: 0.0050 - custom_metric: 0.7323 - val_loss: 0.0040 - val_custom_metric: 0.6006 - lr: 1.1685e-04
#
# Epoch 363: LearningRateScheduler setting learning rate to 0.00011100638221250847.
# Epoch 363/400
# 43/43 [==============================] - 2s 46ms/step - loss: 0.0050 - custom_metric: 0.7313 - val_loss: 0.0039 - val_custom_metric: 0.5974 - lr: 1.1101e-04
#
# Epoch 364: LearningRateScheduler setting learning rate to 0.00010530725558055565.
# Epoch 364/400
# 43/43 [==============================] - 2s 46ms/step - loss: 0.0049 - custom_metric: 0.7275 - val_loss: 0.0038 - val_custom_metric: 0.5899 - lr: 1.0531e-04
#
# Epoch 365: LearningRateScheduler setting learning rate to 9.975594002753496e-05.
# Epoch 365/400
# 43/43 [==============================] - 2s 47ms/step - loss: 0.0050 - custom_metric: 0.7343 - val_loss: 0.0038 - val_custom_metric: 0.5695 - lr: 9.9756e-05
#
# Epoch 366: LearningRateScheduler setting learning rate to 9.435257379664108e-05.
# Epoch 366/400
# 43/43 [==============================] - 2s 47ms/step - loss: 0.0050 - custom_metric: 0.7293 - val_loss: 0.0039 - val_custom_metric: 0.5927 - lr: 9.4353e-05
#
# Epoch 367: LearningRateScheduler setting learning rate to 8.909760799724609e-05.
# Epoch 367/400
# 43/43 [==============================] - 2s 46ms/step - loss: 0.0050 - custom_metric: 0.7331 - val_loss: 0.0038 - val_custom_metric: 0.5830 - lr: 8.9098e-05
#
# Epoch 368: LearningRateScheduler setting learning rate to 8.399134094361216e-05.
# Epoch 368/400
# 43/43 [==============================] - 2s 47ms/step - loss: 0.0050 - custom_metric: 0.7304 - val_loss: 0.0039 - val_custom_metric: 0.6004 - lr: 8.3991e-05
#
# Epoch 369: LearningRateScheduler setting learning rate to 7.903423102106899e-05.
# Epoch 369/400
# 43/43 [==============================] - 2s 47ms/step - loss: 0.0050 - custom_metric: 0.7331 - val_loss: 0.0039 - val_custom_metric: 0.6028 - lr: 7.9034e-05
#
# Epoch 370: LearningRateScheduler setting learning rate to 7.422639464493841e-05.
# Epoch 370/400
# 43/43 [==============================] - 2s 46ms/step - loss: 0.0050 - custom_metric: 0.7351 - val_loss: 0.0037 - val_custom_metric: 0.5572 - lr: 7.4226e-05
#
# Epoch 371: LearningRateScheduler setting learning rate to 6.956831202842295e-05.
# Epoch 371/400
# 43/43 [==============================] - 2s 46ms/step - loss: 0.0050 - custom_metric: 0.7297 - val_loss: 0.0039 - val_custom_metric: 0.6013 - lr: 6.9568e-05
#
# Epoch 372: LearningRateScheduler setting learning rate to 6.506012141471729e-05.
# Epoch 372/400
# 43/43 [==============================] - 2s 46ms/step - loss: 0.0050 - custom_metric: 0.7300 - val_loss: 0.0038 - val_custom_metric: 0.5841 - lr: 6.5060e-05
#
# Epoch 373: LearningRateScheduler setting learning rate to 6.070211748010479e-05.
# Epoch 373/400
# 43/43 [==============================] - 2s 48ms/step - loss: 0.0049 - custom_metric: 0.7217 - val_loss: 0.0039 - val_custom_metric: 0.5995 - lr: 6.0702e-05
#
# Epoch 374: LearningRateScheduler setting learning rate to 5.649459853884764e-05.
# Epoch 374/400
# 43/43 [==============================] - 2s 48ms/step - loss: 0.0050 - custom_metric: 0.7277 - val_loss: 0.0039 - val_custom_metric: 0.5950 - lr: 5.6495e-05
#
# Epoch 375: LearningRateScheduler setting learning rate to 5.243771738605574e-05.
# Epoch 375/400
# 43/43 [==============================] - 2s 47ms/step - loss: 0.0050 - custom_metric: 0.7299 - val_loss: 0.0038 - val_custom_metric: 0.5943 - lr: 5.2438e-05
#
# Epoch 376: LearningRateScheduler setting learning rate to 4.853191785514355e-05.
# Epoch 376/400
# 43/43 [==============================] - 2s 47ms/step - loss: 0.0050 - custom_metric: 0.7327 - val_loss: 0.0039 - val_custom_metric: 0.5954 - lr: 4.8532e-05
#
# Epoch 377: LearningRateScheduler setting learning rate to 4.477749826037325e-05.
# Epoch 377/400
# 43/43 [==============================] - 2s 48ms/step - loss: 0.0050 - custom_metric: 0.7259 - val_loss: 0.0037 - val_custom_metric: 0.5723 - lr: 4.4777e-05
#
# Epoch 378: LearningRateScheduler setting learning rate to 4.1174309444613755e-05.
# Epoch 378/400
# 43/43 [==============================] - 2s 48ms/step - loss: 0.0049 - custom_metric: 0.7217 - val_loss: 0.0039 - val_custom_metric: 0.5903 - lr: 4.1174e-05
#
# Epoch 379: LearningRateScheduler setting learning rate to 3.772295167436823e-05.
# Epoch 379/400
# 43/43 [==============================] - 2s 48ms/step - loss: 0.0050 - custom_metric: 0.7278 - val_loss: 0.0038 - val_custom_metric: 0.5860 - lr: 3.7723e-05
#
# Epoch 380: LearningRateScheduler setting learning rate to 3.4423421311657876e-05.
# Epoch 380/400
# 43/43 [==============================] - 2s 48ms/step - loss: 0.0050 - custom_metric: 0.7310 - val_loss: 0.0039 - val_custom_metric: 0.5999 - lr: 3.4423e-05
#
# Epoch 381: LearningRateScheduler setting learning rate to 3.127601303276606e-05.
# Epoch 381/400
# 43/43 [==============================] - 2s 48ms/step - loss: 0.0049 - custom_metric: 0.7248 - val_loss: 0.0038 - val_custom_metric: 0.5889 - lr: 3.1276e-05
#
# Epoch 382: LearningRateScheduler setting learning rate to 2.828102878993377e-05.
# Epoch 382/400
# 43/43 [==============================] - 2s 47ms/step - loss: 0.0049 - custom_metric: 0.7273 - val_loss: 0.0039 - val_custom_metric: 0.5995 - lr: 2.8281e-05
#
# Epoch 383: LearningRateScheduler setting learning rate to 2.5438323064008728e-05.
# Epoch 383/400
# 43/43 [==============================] - 2s 47ms/step - loss: 0.0050 - custom_metric: 0.7358 - val_loss: 0.0039 - val_custom_metric: 0.5861 - lr: 2.5438e-05
#
# Epoch 384: LearningRateScheduler setting learning rate to 2.2748336050426587e-05.
# Epoch 384/400
# 43/43 [==============================] - 2s 47ms/step - loss: 0.0050 - custom_metric: 0.7292 - val_loss: 0.0039 - val_custom_metric: 0.5898 - lr: 2.2748e-05
#
# Epoch 385: LearningRateScheduler setting learning rate to 2.0211220544297248e-05.
# Epoch 385/400
# 43/43 [==============================] - 2s 49ms/step - loss: 0.0050 - custom_metric: 0.7289 - val_loss: 0.0040 - val_custom_metric: 0.6134 - lr: 2.0211e-05
#
# Epoch 386: LearningRateScheduler setting learning rate to 1.78271257027518e-05.
# Epoch 386/400
# 43/43 [==============================] - 2s 46ms/step - loss: 0.0049 - custom_metric: 0.7267 - val_loss: 0.0039 - val_custom_metric: 0.5892 - lr: 1.7827e-05
#
# Epoch 387: LearningRateScheduler setting learning rate to 1.5596047887811437e-05.
# Epoch 387/400
# 43/43 [==============================] - 2s 47ms/step - loss: 0.0050 - custom_metric: 0.7309 - val_loss: 0.0039 - val_custom_metric: 0.5820 - lr: 1.5596e-05
#
# Epoch 388: LearningRateScheduler setting learning rate to 1.3518289051717147e-05.
# Epoch 388/400
# 43/43 [==============================] - 2s 46ms/step - loss: 0.0049 - custom_metric: 0.7183 - val_loss: 0.0039 - val_custom_metric: 0.5956 - lr: 1.3518e-05
#
# Epoch 389: LearningRateScheduler setting learning rate to 1.159399744210532e-05.
# Epoch 389/400
# 43/43 [==============================] - 2s 48ms/step - loss: 0.0050 - custom_metric: 0.7359 - val_loss: 0.0038 - val_custom_metric: 0.5825 - lr: 1.1594e-05
#
# Epoch 390: LearningRateScheduler setting learning rate to 9.82317123998655e-06.
# Epoch 390/400
# 43/43 [==============================] - 2s 47ms/step - loss: 0.0048 - custom_metric: 0.7179 - val_loss: 0.0038 - val_custom_metric: 0.5786 - lr: 9.8232e-06
#
# Epoch 391: LearningRateScheduler setting learning rate to 8.205811354855541e-06.
# Epoch 391/400
# 43/43 [==============================] - 2s 48ms/step - loss: 0.0048 - custom_metric: 0.7111 - val_loss: 0.0039 - val_custom_metric: 0.5937 - lr: 8.2058e-06
#
# Epoch 392: LearningRateScheduler setting learning rate to 6.742365712852916e-06.
# Epoch 392/400
# 43/43 [==============================] - 2s 48ms/step - loss: 0.0049 - custom_metric: 0.7238 - val_loss: 0.0039 - val_custom_metric: 0.6036 - lr: 6.7424e-06
#
# Epoch 393: LearningRateScheduler setting learning rate to 5.432684247352881e-06.
# Epoch 393/400
# 43/43 [==============================] - 2s 48ms/step - loss: 0.0050 - custom_metric: 0.7289 - val_loss: 0.0039 - val_custom_metric: 0.5967 - lr: 5.4327e-06
#
# Epoch 394: LearningRateScheduler setting learning rate to 4.276917479728581e-06.
# Epoch 394/400
# 43/43 [==============================] - 2s 47ms/step - loss: 0.0050 - custom_metric: 0.7285 - val_loss: 0.0039 - val_custom_metric: 0.5827 - lr: 4.2769e-06
#
# Epoch 395: LearningRateScheduler setting learning rate to 3.2750635909906123e-06.
# Epoch 395/400
# 43/43 [==============================] - 2s 47ms/step - loss: 0.0050 - custom_metric: 0.7284 - val_loss: 0.0038 - val_custom_metric: 0.5838 - lr: 3.2751e-06
#
# Epoch 396: LearningRateScheduler setting learning rate to 2.427272420391091e-06.
# Epoch 396/400
# 43/43 [==============================] - 2s 47ms/step - loss: 0.0049 - custom_metric: 0.7236 - val_loss: 0.0039 - val_custom_metric: 0.5966 - lr: 2.4273e-06
#
# Epoch 397: LearningRateScheduler setting learning rate to 1.7335437405563425e-06.
# Epoch 397/400
# 43/43 [==============================] - 2s 48ms/step - loss: 0.0049 - custom_metric: 0.7161 - val_loss: 0.0039 - val_custom_metric: 0.5946 - lr: 1.7335e-06
#
# Epoch 398: LearningRateScheduler setting learning rate to 1.1938776651732042e-06.
# Epoch 398/400
# 43/43 [==============================] - 2s 47ms/step - loss: 0.0050 - custom_metric: 0.7271 - val_loss: 0.0038 - val_custom_metric: 0.5768 - lr: 1.1939e-06
#
# Epoch 399: LearningRateScheduler setting learning rate to 8.084231808425102e-07.
# Epoch 399/400
# 43/43 [==============================] - 2s 47ms/step - loss: 0.0049 - custom_metric: 0.7209 - val_loss: 0.0038 - val_custom_metric: 0.5858 - lr: 8.0842e-07
#
# Epoch 400: LearningRateScheduler setting learning rate to 5.770312441200076e-07.
# Epoch 400/400
# 43/43 [==============================] - 2s 47ms/step - loss: 0.0049 - custom_metric: 0.7263 - val_loss: 0.0039 - val_custom_metric: 0.5975 - lr: 5.7703e-07

# %% [markdown]
# Export trained model.

# %%
model.save(checkpoint_filepath)

# %% [markdown]
# Show some training info.

# %%
#Show training results

min_metric_epoch = tf.math.argmin(History.history['custom_metric'])
min_metric = History.history['custom_metric'][min_metric_epoch]
loss_min_metric = History.history['loss'][min_metric_epoch]
val_metric = History.history['val_custom_metric'][min_metric_epoch]
val_loss = History.history['val_loss'][min_metric_epoch]

print('Best model at epoch', (min_metric_epoch.numpy() + 1))
print('Metric:', min_metric)
print('Loss:', loss_min_metric)
print('Validation metric:', val_metric)
print('Validation loss:', val_loss)
# Out:
# Best model at epoch 391
# Metric: 0.7111208438873291
# Loss: 0.0048195915296673775
# Validation metric: 0.5936923027038574
# Validation loss: 0.0038871769793331623

# %% [markdown]
# Show training progess.

# %%
start_epoch_loss = 100
epochs_interval_loss = range(start_epoch_loss, epochs)
start_epoch_metric = 100
epochs_interval_metric = range(start_epoch_metric, epochs)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15,4))

ax1.plot(epochs_interval_loss, History.history['loss'][start_epoch_loss:], label='Loss')
ax1.plot(epochs_interval_loss, History.history['val_loss'][start_epoch_loss:], label='Validation Loss')
ax1.set_xlabel("Epochs")
ax1.legend(loc='upper right')

ax2.plot(epochs_interval_metric, History.history['custom_metric'][start_epoch_metric:], label='Metric')
ax2.plot(epochs_interval_metric, History.history['val_custom_metric'][start_epoch_metric:], label='Validation Metric')
ax2.set_xlabel("Epochs")
ax2.legend(loc='upper right')

plt.show()

# %% [markdown]
# # Load best model and make predictions

# %% [markdown]
# Define test set preprocessing functions.

# %%
def normalize_test(image, label, height, width, std_vec, max_gt_values):             #Function to normalize the test dataset
    image = tf.cast(image,tf.float32)
    image = image/std_vec
    label = label/max_gt_values

    return image, label, height, width

def image_repetition_test(image, height, width):    #Function that repeats small images applying random flips to create a bigger image
    nx = tf.math.floordiv(target_image_size, tf.cast(width, tf.int32))
    ny = tf.math.floordiv(target_image_size, tf.cast(height, tf.int32))
    
    image = tf.tile(image, [ny, nx, 1])
    image = tf.cond(tf.math.maximum(nx, ny)==1, lambda: tf.image.resize(image, [target_image_size, target_image_size], method='bilinear', antialias=False), lambda: tf.image.pad_to_bounding_box(image, 0, 0, target_image_size, target_image_size))

    return image

def pad_with_patches_test(image, label, height, width):    #Function to resize images
    max_dim = tf.math.maximum(height, width)
    image = tf.cond(max_dim<target_image_size, lambda: image_repetition_test(image, height, width), lambda: tf.image.resize(image, [target_image_size, target_image_size], method='bilinear', antialias=False))

    return image, label

def select_bands(image, label, height, width, band_index):
    image = tf.gather(image, band_index, axis = 2)

    return image, label, height, width

# %% [markdown]
# Preprocessing of test dataset.

# %%
test_data = load_tf_records(tf_records_path.format(test_partition_id)).map(decode_dataset, num_parallel_calls=AUTO)

test_data = test_data.map(lambda image, label, height, width: normalize_test(image, label, height, width, std_vec, max_gt_values), num_parallel_calls=AUTO)    #normalize test dataset
test_data = test_data.map(lambda image, label, height, width: select_bands(image, label, height, width, band_selection_index), num_parallel_calls=AUTO)
test_data = test_data.map(lambda image, label, height, width: pad_with_patches_test(image, label, height, width), num_parallel_calls=AUTO).cache()    #pad test dataset
test_data = test_data.batch(batch_size=batch_size, drop_remainder=False).prefetch(AUTO)    #batch and prefetch test dataset

# %% [markdown]
# Print some entries from test dataset.

# %%
n_images = 10
k = min(n_bands, 10)

for image, label in test_data.unbatch().take(n_images):
    fig, axs = plt.subplots(1, k, figsize=(25*k/10, 7*k/10))
    for i in range(k):
        axs[i].imshow(image[:,:,n_bands-1-i])

plt.show()

# %% [markdown]
# Load the exported model.

# %%
loaded_model = keras.models.load_model(checkpoint_filepath, custom_objects={'custom_metric': custom_metric})

loaded_model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetlite0 (Function  (None, 1, 1, 1280)       687136
#  al)
#
#  flatten_5 (Flatten)         (None, 1280)              0
#
#  dense_5 (Dense)             (None, 4)                 5124
#
# =================================================================
# Total params: 692,260
# Trainable params: 678,020
# Non-trainable params: 14,240
# _________________________________________________________________

# %% [markdown]
# Make predictions and generate csv file.

# %%
predictions = loaded_model.predict(test_data)

submission = pd.DataFrame(data=predictions, columns=["P", "K", "Mg", "pH"])
submission.to_csv(predictions_filepath, index_label="sample_index")

# %% [markdown]
# Evaluate model performance.

# %%
gt = np.array(list(test_data.unbatch().map(lambda image, label: label)))

score = custom_metric(gt, predictions)

print(score.numpy())
# Out:
# 0.8305638
